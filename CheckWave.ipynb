# %%
from KRZmetric import *
import numpy as np
import matplotlib.pyplot as plt

# %%
#赤道面 非Kerr 轨道
p=6;
ecc=0.5
d1=0.0
spin=0.5

rmax = p / (1 - ecc);
rmin = p / (1 + ecc);
r0 = rmax;
th0=np.pi/2.0
invgmax=metric_KRZ_inverse(spin, d1, rmax, th0);
invgmin=metric_KRZ_inverse(spin, d1, rmin, th0);


EoverL = ((invgmax[3][0] - invgmin[3][0]) + sqrt((invgmax[3][0] - invgmin[3][0]) *(invgmax[3][0] - invgmin[3][0]) - (invgmax[0][0] - invgmin[0][0])*(invgmax[3][3] - invgmin[3][3]))) / (invgmax[0][0] - invgmin[0][0]);
Lz = sqrt((invgmax[3][0] - invgmin[3][0]) / (EoverL*EoverL*(invgmin[3][0] * invgmax[0][0] - invgmax[3][0] * invgmin[0][0]) + (invgmin[3][0] * invgmax[3][3] - invgmax[3][0] * invgmin[3][3])));

E = EoverL*Lz;
iota=0;Q=0;
print(E,Lz)
print('krz_d[1]= %f; spin = %f;current_p = %f;current_e = %f;current_iota = %f;\nE=%.10f;Lz=%.10f; Q=%.10f;'%(d1,spin,p,ecc,iota,E,Lz,Q))
# Out:
# 0.945196560826 3.13046788241
# krz_d[1]= 0.000000; spin = 0.500000;current_p = 6.000000;current_e = 0.500000;current_iota = 0.000000;
# E=0.9451965608;Lz=3.1304678824; Q=0.0000000000;

# %%
M=1e6
mu=1e-3
spin = 0.500000;p = 6.5000000;e = 0.50000;iota = 0.;
#[E,Lz,Q]=getELQ(e,p,iota,spin)
print([E,Lz,Q])
d1=0;d2=0;d3=0;

# %%
orbfilename1='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\flux\\flux\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)
orbfilename2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\RK45\\RK45\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)
kfilename1='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\flux\\flux\\nk_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)
kfilename2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\RK45\\RK45\\nk_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)
wavefilename='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\flux\\flux\\wave_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
index, myt_sec, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(orbfilename1,unpack=True)
#index2, myt_sec2, tau2,t2,r2,th2,phi2,ut2,ur2,uth2,uphi2,F_t2,F_r2,F_th2,F_phi2=np.loadtxt(orbfilename2,unpack=True)

# %%
tk1,k11,k21,k31,k41,k51,k61=np.loadtxt(kfilename1,unpack=True)
#tk2,k12,k22,k32,k42,k52,k62=np.loadtxt(kfilename2,unpack=True)

# %%
t_sec,wave_p,wave_c=np.loadtxt(wavefilename,unpack=True)

# %%
#t_sec2,wave2=getwave(orbfilename2,mu=mu,THETA=90)
t_sec1,wave1=getwave(orbfilename1,mu=mu,THETA=90)

# %%
fig=plt.figure()
Grav = 6.674e-11;
clight = 2.998e8;
Msol = 1.989e30; 
M=1e6
#plt.plot(t_sec*clight*clight*clight / M / Msol / Grav,wave_p*1.2)
plt.plot(t_sec1*clight*clight*clight / M / Msol / Grav,np.real(wave1))
#plt.plot(t_sec2*clight*clight*clight / M / Msol / Grav,np.real(wave2),':')
fig.set_size_inches(20, 5)
#plt.ylim(-1e-22,1e-22)
plt.xlim(0,2e3)
# Out:
# (0, 2000.0)

# %%
fig=plt.figure()
plt.plot(t,F_r,'.')
plt.plot(t2,F_r2,':')
fig.set_size_inches(20, 5)
#plt.xlim(385,400)
#plt.ylim(-1e-3,1e-3)

# %%
plt.plot(tau,phi,':')
plt.xlim(0,1000)
#plt.ylim(0,10)
# Out:
# (0, 1000)
