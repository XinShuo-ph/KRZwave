# %%
from KRZmetric import *
import numpy as np

# %%
np.num2str([1.0,1.0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-424a0278ff09> in <module>()
# ----> 1 np.num2str([1.0,1.0])
#
# AttributeError: module 'numpy' has no attribute 'num2str'

# %%
import matplotlib.pyplot as plt

# %%
filename='EMRIsuite_traj.dat'
tlist,plist,elist,iotalist,Elist,Llist,Qlist=np.loadtxt(filename,unpack=True)

# %%
M=1e6
spin=0.9
d1=0;d2=0;d3=0;
E,Lz,Q=getELQ(0.5,10,np.pi/4,0.9)
filename2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\flux\\flux\\NK_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
E,Lz,Q
# Out:
# (0.96429235004262392, 2.5260208894718561, 6.4091883408261427)

# %%
tlist2,rlist,thlist,philist,Elist2,Llist2,Qlist2=np.loadtxt(filename2,unpack=True)

# %%
plt.plot(tlist,Elist,label='EMRIsuite')
plt.plot(tlist2,Elist2,':',label='test')
#plt.plot(tlist,Llist,label='EMRIsuite')
#plt.plot(tlist2,Llist2,':',label='test')
#plt.plot(tlist,Qlist,label='EMRIsuite')
#plt.plot(tlist2/1.1,Qlist2,'.',label='test')
plt.xlabel('t/M')
plt.ylabel('E')
plt.ylim(0.9,1)
plt.legend()
#plt.xlim(20000,100000)
#plt.ylim(0.96,0.962)

# %%
plt.plot(tlist,Llist,label='EMRIsuite')
plt.plot(tlist2,Llist2,':',label='test')
#plt.plot(tlist,Llist,label='EMRIsuite')
#plt.plot(tlist2,Llist2,':',label='test')
#plt.plot(tlist,Qlist,label='EMRIsuite')
#plt.plot(tlist2/1.1,Qlist2,'.',label='test')
plt.xlabel('t/M')
plt.ylabel('Lz')
#plt.ylim(0.9,1)
plt.legend()
#plt.xlim(0,10000)

# %%
plt.plot(tlist2,rlist,'.',label='test')
plt.plot(tlist,plist/(1+elist),label='EMRIsuite')
plt.plot(tlist,plist/(1-elist),label='EMRIsuite')
plt.ylabel('r')
plt.xlabel('t/M')
#plt.xlim(40000,70000)
plt.legend()

# %%
plt.plot(tlist2,rlist*cos(thlist),'.',label='test')
plt.plot(tlist,iotalist,label='EMRIsuite')
#plt.plot(tlist,np.pi/2-iotalist,label='EMRIsuite')
plt.xlabel('t/M')
plt.ylabel('$\\theta$')
plt.legend()
#plt.ylim(-1,1)
plt.xlim(0,2000)
# Out:
# (0, 2000)

# %%
10/1.5
# Out:
# 6.666666666666667

# %%
filename2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\flux\\flux\\flux_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

tau, t, ut, Elist, Llist, Qlist, Eflux, Lflux, Qflux= np.loadtxt(filename2,unpack=True)

# %%
eflist=np.zeros(len(Elist));
eflist[0]=Eflux[0]*ut[0]*1e-4;
eflist

for i in np.arange(len(Elist)):
    if i==0:
        continue
        
    eflist[i]=(Elist[i]-Elist[i-1])/(tau[i]-tau[i-1])

plt.plot(tau,eflist,'.')
plt.plot(tau,Eflux*ut)
#plt.ylim(-1.25e-7,-7e-8)
#plt.xlim(0,400)

# %%
eftlist=np.zeros(len(Elist));
eftlist[0]=Eflux[0];


for i in np.arange(len(Elist)):
    if i==0:
        continue
        
    eftlist[i]=(Elist[i]-Elist[i-1])/(t[i]-t[i-1])

plt.plot(tau,eftlist)
plt.plot(tau,Eflux,":")
#plt.ylim(-1.25e-7,-7e-8)
#plt.xlim(0,400)

# %%
plt.plot(tau,rlist[0:-1])
plt.xlim(0,400)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-231-9a1bb6fd9e3c> in <module>()
# ----> 1 plt.plot(tau,rlist[0:-1])
#       2 plt.xlim(0,400)
#
# D:\ProgramFiles\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# D:\ProgramFiles\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ...

# %%
lflist=np.zeros(len(Elist));
lflist[0]=Lflux[0];
lflist
for i in np.arange(len(Elist)):
    if i==0:
        continue
    lflist[i]=(Llist[i]-Llist[i-1])/(tau[i]-tau[i-1])

# %%
plt.plot(tau,lflist)
plt.plot(tau,Lflux*ut,':')
#plt.xlim(0,400)

# %%
qflist=np.zeros(len(Qlist));
qflist[0]=Qflux[0]*ut[0]*1e-4;
qflist
for i in np.arange(len(Qlist)):
    if i==0:
        continue
    qflist[i]=(Qlist[i]-Qlist[i-1])/(tau[i]-tau[i-1])

# %%
plt.plot(tau,qflist,'.')
plt.plot(tau,Qflux*ut)
#plt.xlim(0,400)

# %%
from KRZmetric import *
import numpy as np
import matplotlib.pyplot as plt

# %%
M=1e6
spin=0.9
d1=0;d2=0;d3=0;
e=0.5
p=10
iota=np.pi/4
E,Lz,Q=getELQ(e,p,iota,spin)
filename2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\flux\\flux\\NK_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
tlist2,rlist,thlist,philist,Elist2,Llist2,Qlist2,elist,plist=np.loadtxt(filename2,unpack=True)

# %%
plt.plot(plist,elist,'b:')
plt.xlim(2,20)
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
plt.plot(tlist2,rlist,':')

plt.plot(tlist2,plist/(1+elist),label='EMRIsuite')
plt.plot(tlist2,plist/(1-elist),label='EMRIsuite')
plt.xlim(4100000,4150000)
plt.ylim(0,10)
# Out:
# (0, 10)

# %%
plt.plot(plist,elist,'b:')
plt.xlim(2,20)
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
elist[np.where(plist<5)]
# Out:
# array([ 0.02261938,  0.02261938,  0.02261938, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.where(abs(elist-0.02261938)<1e-6)
# Out:
# (array([113125, 113126, 113127, 113128, 113129, 113130, 113131, 113132,
#         113133, 113134, 113135, 113136, 113137, 113138, 113139, 113140,
#         113141, 113142, 113143, 113144, 113145, 113146, 113147, 113148,
#         113149, 113150, 113151, 113152, 113153, 113154, 113155, 113156,
#         113157, 113158, 113159, 113160, 113161, 113162, 113163, 113164,
#         113165, 113166, 113167, 113168, 113169, 113170, 113171, 113172,
#         113173, 113174, 113175], dtype=int64),)

# %%
plist[np.where(abs(elist-0.02261938)<1e-6)]
# Out:
# array([ 4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078,  4.99940078,  4.99940078,  4.99940078,  4.99940078,
#         4.99940078])
