# %%
import numpy as np
from KRZmetric import *
import matplotlib.pyplot as plt

# %%
M=2e5; spin=0.5; d1=0.2; e=0.5; p=6

# %%
filenamepre='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\RK4geo8_dt\\RK4geo8_dt\\trace_M%.0f_spin%.6f_d1%.6f_e%.6f_p%.6f.dat'%(M,spin,d1,e,p)
index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamepre,unpack=True)

# %%
filenamenow='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,e,p,d1,0,0)
index, tau2,t2,r2,th2,phi2,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamepre,unpack=True)

# %%
plt.figure(figsize=[20,5])
plt.plot(t,phi-phi2)
#plt.plot(t2,r2)
plt.xlim(0,100000)
plt.ylim(-1e-55,1e-55)
# Out:
# (-1e-55, 1e-55)

# %%
#conclusion: good!

# %%
#next: see the relation between d2 and varied spin/Mass

# %%
M=2e5
spin=0.200
e=0.6
p=10
d1=0
d3=0
dlist=[]
Mlist=[]
spinlist=[]

for d2 in np.arange(-0.2,0.6,0.1):
    filename='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,e,p,d1,d2,d3)
    index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filename,unpack=True)


    avgomgsec=getfreq_sec_frommaxi(t,r,phi,M)
    print(avgomgsec)
    avgomgr=avgomgsec[0]
    avgomgphi=avgomgsec[1]

    def fun(x):
        print('called')
        M=x[0]
        spin=x[1]
        print('e=%f, p=%f, M=%f, spin=%f, aimomgr=%f, aimomgphi=%f'%(e,p,M,spin,avgomgr,avgomgphi))

        omgr,omgphi=getfreq_sec_fromepma(e,p,M,spin)
        avgomgsec=np.array([avgomgr,avgomgphi])
        omgsec=np.array([omgr,omgphi])
        return (omgsec-avgomgsec)/avgomgsec


    from scipy.optimize import root,fsolve
    (myM,myspin)=fsolve(fun,[M,spin])

    getfreq_sec_fromepma(e,p,myM,myspin)

    dlist.append(d2)
    spinlist.append(myspin)
    Mlist.append(myM)
    for i in range(len(dlist)):
        print([dlist[i],spinlist[i],Mlist[i]])
# Out:
# [ 0.01223306  0.01959153]
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=200000.002980, spin=0.200000, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=199513.843312, spin=-0.003556, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=199601.017235, spin=0.015428, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=199591.902275, spin=0.013764, aimomgr=0.012233, aimomgphi=0.019592
# called
# e=0.600000, p=10.000000, M=199591.801139, spin=0.013749, aimomgr=0.012233, aimomgphi=0.019592
# called
# ...

# %%
spinl4=spinlist
Ml4=Mlist

# %%
plt.figure(figsize=[12,8])
plt.plot(np.arange(-0.2,0.6,0.01),1.58*np.arange(-0.2,0.6,0.01),'b--')
plt.plot(np.arange(-0.2,0.6,0.01),2.2*np.arange(-0.2,0.6,0.01),'b--')
plt.plot(np.arange(-0.2,0.6,0.01),2.4*np.arange(-0.2,0.6,0.01),'b--')
plt.plot(np.arange(-0.2,0.6,0.01),4.8*np.arange(-0.2,0.6,0.01),'b--')
plt.plot(np.arange(-0.2,0.6,0.01),0.6*np.arange(-0.2,0.6,0.01),'b--')
plt.plot(np.arange(-0.2,0.6,0.01),np.zeros([80]),'y--')
plt.plot(dlist[1:7],(np.array(spinl1[1:7])-0.5)/0.5,'ro',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.1,\, 5)$')
plt.plot(dlist[1:7],(np.array(Ml1[1:7])-2e5)/2e5,'*',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.1,\, 5)$')
plt.plot(dlist[1:7],(np.array(spinl[1:7])-0.5)/0.5,'bo',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.5,\, 6)$')
plt.plot(dlist[1:7],(np.array(Ml[1:7])-2e5)/2e5,'+',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.5,\, 6)$')
plt.plot(dlist,(np.array(spinl2)-0.5)/0.5,'go',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.6,\, 10)$')
plt.plot(dlist,(np.array(Ml2)-2e5)/2e5,'x',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.6,\, 10)$')
plt.plot(dlist[0:7],(np.array(spinl3[0:7])-0.8)/0.8,'yo',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.8,\, 2\\times10^5,\, 0.6,\, 10)$')
plt.plot(dlist,(np.array(Ml3)-2e5)/2e5,'+',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.8,\, 2\\times10^5,\, 0.6,\, 10)$')
plt.plot(dlist,(np.array(spinl4)-0.2)/0.2,'ko',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.2,\, 2\\times10^5,\, 0.6,\, 10)$')

plt.xlabel('$\\delta _2$',fontsize=16)
plt.legend()
plt.savefig('d2_deltaspin.png',dpi=600)

# %%
#d2=0.5处是没找到
#d2=-0.2处有点奇怪，看看匹配率
Mlist
# Out:
# [223374.3549193319,
#  200316.57014684108,
#  199999.79850960217,
#  199453.09882214802,
#  198768.03992356206,
#  197958.89806202019,
#  197027.68300958042,
#  198407.76958101938]

# %%
spinlist
# Out:
# [0.39295967370403123,
#  0.38376819170002191,
#  0.50000200827101848,
#  0.61791695922449097,
#  0.73819572314596682,
#  0.86114087484880897,
#  0.98710421998459053,
#  0.85415250333162529]

# %%
filenamekrz='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,e,p,d1,-0.2,d3)
filenamekerr='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(Ml1[0],spinl1[0],e,p,d1,0,d3)

# %%
TH=np.pi/4
PH=0
krzwave=getwave(filenamekrz,TH,PH)

# %%
kerrwave=getwave(filenamekerr,TH,PH)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),krzwave[1])
plt.plot(np.arange(100000),kerrwave[1],'--')
plt.xlim(98000,100000)
# Out:
# D:\ProgramFiles\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (98000, 100000)

# %%
bracket(kerrwave[1],krzwave[1],1)/np.sqrt( bracket(kerrwave[1],kerrwave[1],1)*bracket(krzwave[1],krzwave[1],1) )
# Out:
# 0.80510482262753091

# %%
#d2=-0.2时，匹配率只有0.80！！

# %%
#看看d2=-0.1的匹配率

# %%
d2=-0.1
filenamekrz='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,e,p,d1,d2,d3)
filenamekerr='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(Ml1[1],spinl1[1],e,p,0,0,0)

# %%
TH=np.pi/4
PH=0
krzwave=getwave(filenamekrz,TH,PH)

# %%
kerrwave=getwave(filenamekerr,TH,PH)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),krzwave[1],linewidth=3)
plt.plot(np.arange(100000),kerrwave[1],'--')
plt.xlim(99000,100000)
# Out:
# D:\ProgramFiles\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (99000, 100000)

# %%
bracket(kerrwave[1],krzwave[1],1)/np.sqrt( bracket(kerrwave[1],kerrwave[1],1)*bracket(krzwave[1],krzwave[1],1) )
# Out:
# 0.99998634047816426

# %%
M=2e5
spin=0.200
e=0.6
p=10
d1=0.2
d3=0
dlist=[]
Mlist=[]
spinlist=[]

for d2 in np.arange(-0.2,0.6,0.1):
    filename='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,e,p,d1,d2,d3)
    index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filename,unpack=True)


    avgomgsec=getfreq_sec_frommaxi(t,r,phi,M)
    print(avgomgsec)
    avgomgr=avgomgsec[0]
    avgomgphi=avgomgsec[1]

    def fun(x):
        print('called')
        M=x[0]
        spin=x[1]
        print('e=%f, p=%f, M=%f, spin=%f, aimomgr=%f, aimomgphi=%f'%(e,p,M,spin,avgomgr,avgomgphi))

        omgr,omgphi=getfreq_sec_fromepma(e,p,M,spin)
        avgomgsec=np.array([avgomgr,avgomgphi])
        omgsec=np.array([omgr,omgphi])
        return (omgsec-avgomgsec)/avgomgsec


    from scipy.optimize import root,fsolve
    (myM,myspin)=fsolve(fun,[M,spin])

    getfreq_sec_fromepma(e,p,myM,myspin)

    dlist.append(d2)
    spinlist.append(myspin)
    Mlist.append(myM)
    for i in range(len(dlist)):
        print([dlist[i],spinlist[i],Mlist[i]])
# Out:
# [ 0.01246502  0.01916595]
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200000.002980, spin=0.200000, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200000.000000, spin=0.200000, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200285.491218, spin=0.137500, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200292.703156, spin=0.139131, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200292.539713, spin=0.139083, aimomgr=0.012465, aimomgphi=0.019166
# called
# e=0.600000, p=10.000000, M=200292.539688, spin=0.139083, aimomgr=0.012465, aimomgphi=0.019166
# ...

# %%
d12_spinl4=spinlist
d12_Ml4=Mlist

# %%
plt.figure(figsize=[12,8])
#plt.plot(np.arange(-0.2,0.6,0.01),1.58*np.arange(-0.2,0.6,0.01),'b--')
#plt.plot(np.arange(-0.2,0.6,0.01),2.2*np.arange(-0.2,0.6,0.01),'b--')
#plt.plot(np.arange(-0.2,0.6,0.01),2.4*np.arange(-0.2,0.6,0.01),'b--')
plt.plot(np.arange(-0.2,0.6,0.01),5*np.arange(-0.2,0.6,0.01)+0.65,'b--')
#plt.plot(np.arange(-0.2,0.6,0.01),0.6*np.arange(-0.2,0.6,0.01),'b--')
#plt.plot(np.arange(-0.2,0.6,0.01),np.zeros([80]),'y--')
#plt.plot(dlist[1:7],(np.array(spinl1[1:7])-0.5)/0.5,'ro',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.1,\, 5)$')
#plt.plot(dlist[1:7],(np.array(Ml1[1:7])-2e5)/2e5,'*',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.1,\, 5)$')
#plt.plot(dlist[1:7],(np.array(spinl[1:7])-0.5)/0.5,'bo',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.5,\, 6)$')
#plt.plot(dlist[1:7],(np.array(Ml[1:7])-2e5)/2e5,'+',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.5,\, 6)$')
#plt.plot(dlist,(np.array(spinl2)-0.5)/0.5,'go',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.6,\, 10)$')
#plt.plot(dlist,(np.array(Ml2)-2e5)/2e5,'x',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.5,\, 2\\times10^5,\, 0.6,\, 10)$')
#plt.plot(dlist[0:7],(np.array(spinl3[0:7])-0.8)/0.8,'yo',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.8,\, 2\\times10^5,\, 0.6,\, 10)$')
#plt.plot(dlist,(np.array(Ml3)-2e5)/2e5,'+',label='$\\delta M/M_0,\, (a_0,\, M_0,\, e,\, p)=(0.8,\, 2\\times10^5,\, 0.6,\, 10)$')
plt.plot(dlist,(np.array(d12_spinl4)-0.2)/0.2,'ko',markerfacecolor='none',label='$\\delta a/a_0,\, (a_0,\, M_0,\, e,\, p)=(0.2,\, 2\\times10^5,\, 0.6,\, 10)$')
plt.text(0.4,0,'$\\delta_1=0.2$',fontsize=20)
plt.xlabel('$\\delta _2$',fontsize=16)
plt.legend()
#plt.savefig('d2_deltaspin.png',dpi=600)

# %%
d1=0.2; d2=-0.2
filenamekrz='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,e,p,d1,d2,d3)
filenamekerr='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\multiple_d\\multiple_d\\trace_M%.0f_spin%.6f_e%.6f_p%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(Mlist[0],spinlist[0],e,p,0,0,0)

# %%
TH=np.pi/4
PH=0
krzwave=getwave(filenamekrz,TH,PH)

# %%
kerrwave=getwave(filenamekerr,TH,PH)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),np.real(krzwave[1]),label='KRZ')
plt.plot(np.arange(100000),np.real(kerrwave[1]),'.',label='Kerr')
plt.xlim(98000,100000)
plt.legend()

# %%
bracket(kerrwave[1],krzwave[1],1)/np.sqrt( bracket(kerrwave[1],kerrwave[1],1)*bracket(krzwave[1],krzwave[1],1) )
# Out:
# 0.99998696253614827

# %%
spinlist
# Out:
# [0.13908282926856927,
#  0.23545716586157464,
#  0.33309348543679579,
#  0.43218292540951764,
#  0.53295007047802101,
#  0.63558862568582075,
#  0.7403575583914388,
#  0.84749290877687511]

# %%
Mlist
# Out:
# [200292.53968816961,
#  200484.61426176061,
#  200635.12273961547,
#  200749.20462758851,
#  200827.36338033149,
#  200874.73969359376,
#  200890.31056239369,
#  200877.81455217992]
