# %%
from KRZmetric import *

# %%
def getfreq_fromepa_npsum(e,p,spin):

    rmax=p/(1-e)
    rmin=p/(1+e)
    print('called')
    invgmin=metric_KRZ_inverse(spin,0,rmin,np.pi/2)
    invgmax=metric_KRZ_inverse(spin,0,rmax,np.pi/2)

    EoverL = ((invgmax[3][0] - invgmin[3][0]) + sqrt((invgmax[3][0] - invgmin[3][0]) *(invgmax[3][0] - invgmin[3][0]) - (invgmax[0][0] - invgmin[0][0])*(invgmax[3][3] - invgmin[3][3]))) / ( invgmax[0][0]-invgmin[0][0] );
    Lz = sqrt( (invgmax[3][0]-invgmin[3][0]) / ( EoverL*EoverL*( invgmin[3][0]*invgmax[0][0] - invgmax[3][0]*invgmin[0][0] )+ ( invgmin[3][0]*invgmax[3][3]- invgmax[3][0]*invgmin[3][3] )  )   );
    E=Lz*EoverL
    Q=0

    dchi=1e-6#积分的精度
    chi=np.linspace(dchi/2,np.pi-dchi/2,int(np.pi/dchi))

    #reference: https://arxiv.org/pdf/gr-qc/0202090.pdf (39)-(42)
    myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*np.power(1+e*np.cos(chi),2)
    myH=1-2/p*(1+e*cos(chi))+(spin**2)/(p**2)*np.power(1+e*np.cos(chi),2)
    myG=Lz-2*(Lz-spin*E)/p*(1+e*np.cos(chi))

    myY=p**2*dchi*np.sum(np.multiply( np.power(1+e*np.cos(chi),-2) ,np.power(myJ,-0.5) ))
    myZ=dchi*np.sum(np.multiply(myG, np.multiply( np.power(myH,-1),np.power(myJ,-0.5) ) ))

    myomgr=np.pi*p/(1-e**2)/myY
    myomgphi=myZ/myY

    return myomgr,myomgphi

# %%
e=0.5;p=6.0;a=0.5
getfreq_fromepa(e,p,a)
# Out:
# called
# (0.03230240304396783, 0.067772865947904132)

# %%
e=0.5;p=6.5;a=0.5
for e in np.arange(0.1,0.9,0.1):
    for p in np.arange(6,10,1):
        for a in np.arange(0.1,0.9,0.1):
            print('%f,%f,%f'%(e,p,a))
            print(np.array(getfreq_dt_fromepa(e,p,a))/np.array(getfreq_fromepa(e,p,a)))
# Out:
# 0.100000,6.000000,0.100000
# called
# [ 0.70859071  0.70859086]
# 0.100000,6.000000,0.200000
# called
# [ 0.71631227  0.71631242]
# 0.100000,6.000000,0.300000
# called
# [ 0.72155679  0.72155694]
# 0.100000,6.000000,0.400000
# called
# [ 0.72615007  0.72615022]
# 0.100000,6.000000,0.500000
# called
# [ 0.73039502  0.73039518]
# 0.100000,6.000000,0.600000
# called
# [ 0.73439268  0.73439283]
# 0.100000,6.000000,0.700000
# called
# [ 0.7381892   0.73818935]
# 0.100000,6.000000,0.800000
# called
# [ 0.74181042  0.74181058]
# 0.100000,7.000000,0.100000
# called
# [ 0.75993003  0.75993019]
# 0.100000,7.000000,0.200000
# called
# [ 0.76309038  0.76309054]
# 0.100000,7.000000,0.300000
# called
# [ 0.76606574  0.7660659 ]
# 0.100000,7.000000,0.400000
# called
# [ 0.76889819  0.76889835]
# 0.100000,7.000000,0.500000
# called
# [ 0.7716103   0.77161047]
# 0.100000,7.000000,0.600000
# called
# [ 0.77421592  0.77421608]
# 0.100000,7.000000,0.700000
# called
# [ 0.77672439  0.77672455]
# 0.100000,7.000000,0.800000
# called
# [ 0.77914258  0.77914274]
# 0.100000,8.000000,0.100000
# called
# [ 0.79393323  0.7939334 ]
# 0.100000,8.000000,0.200000
# called
# [ 0.79601821  0.79601838]
# 0.100000,8.000000,0.300000
# called
# [ 0.79802753  0.7980277 ]
# 0.100000,8.000000,0.400000
# called
# [ 0.79996872  0.79996889]
# 0.100000,8.000000,0.500000
# called
# [ 0.80184715  0.80184732]
# 0.100000,8.000000,0.600000
# called
# [ 0.80366686  0.80366703]
# 0.100000,8.000000,0.700000
# called
# [ 0.80543104  0.80543121]
# 0.100000,8.000000,0.800000
# called
# [ 0.80714233  0.8071425 ]
# 0.100000,9.000000,0.100000
# called
# [ 0.81929948  0.81929965]
# 0.100000,9.000000,0.200000
# called
# [ 0.82078833  0.8207885 ]
# 0.100000,9.000000,0.300000
# called
# [ 0.82223485  0.82223502]
# 0.100000,9.000000,0.400000
# called
# [ 0.82364148  0.82364166]
# 0.100000,9.000000,0.500000
# called
# [ 0.82501022  0.82501039]
# 0.100000,9.000000,0.600000
# called
# [ 0.8263427   0.82634288]
# 0.100000,9.000000,0.700000
# called
# [ 0.82764034  0.82764051]
# 0.100000,9.000000,0.800000
# called
# [ 0.82890436  0.82890454]
# 0.200000,6.000000,0.100000
# called
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:687: RuntimeWarning: invalid value encountered in sqrt
#   Tr_=2*Vt/J/np.sqrt(Vr)
# D:\ProgramFiles\lib\site-packages\scipy\integrate\quadpack.py:364: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg, IntegrationWarning)
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:714: RuntimeWarning: invalid value encountered in sqrt
#   Dp_=2*Vphi/J/np.sqrt(Vr)
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in power
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in power
# [ nan  nan]
# 0.200000,6.000000,0.200000
# called
# [ 0.71567305  0.7156732 ]
# 0.200000,6.000000,0.300000
# called
# [ 0.72414409  0.72414424]
# 0.200000,6.000000,0.400000
# called
# [ 0.73006343  0.73006358]
# 0.200000,6.000000,0.500000
# called
# [ 0.73501482  0.73501497]
# 0.200000,6.000000,0.600000
# called
# [ 0.73943188  0.73943203]
# 0.200000,6.000000,0.700000
# called
# [ 0.74349013  0.74349029]
# 0.200000,6.000000,0.800000
# called
# [ 0.74727705  0.74727721]
# 0.200000,7.000000,0.100000
# called
# [ 0.7629523   0.76295246]
# 0.200000,7.000000,0.200000
# called
# [ 0.76687793  0.76687809]
# 0.200000,7.000000,0.300000
# called
# [ 0.77032171  0.77032187]
# 0.200000,7.000000,0.400000
# called
# [ 0.77345915  0.77345931]
# 0.200000,7.000000,0.500000
# called
# [ 0.77637634  0.7763765 ]
# 0.200000,7.000000,0.600000
# called
# [ 0.77912146  0.77912162]
# 0.200000,7.000000,0.700000
# called
# [ 0.78172418  0.78172434]
# 0.200000,7.000000,0.800000
# called
# [ 0.78420418  0.78420434]
# 0.200000,8.000000,0.100000
# called
# [ 0.79789674  0.79789691]
# 0.200000,8.000000,0.200000
# called
# [ 0.80020042  0.80020058]
# 0.200000,8.000000,0.300000
# called
# [ 0.80236552  0.80236569]
# 0.200000,8.000000,0.400000
# called
# [ 0.80441856  0.80441872]
# 0.200000,8.000000,0.500000
# called
# [ 0.80637697  0.80637714]
# 0.200000,8.000000,0.600000
# called
# [ 0.80825291  0.80825307]
# 0.200000,8.000000,0.700000
# called
# [ 0.81005519  0.81005535]
# 0.200000,8.000000,0.800000
# called
# [ 0.81179048  0.81179065]
# 0.200000,9.000000,0.100000
# called
# [ 0.82328531  0.82328549]
# 0.200000,9.000000,0.200000
# called
# [ 0.82486224  0.82486241]
# 0.200000,9.000000,0.300000
# called
# [ 0.82637447  0.82637464]
# 0.200000,9.000000,0.400000
# called
# [ 0.82782956  0.82782974]
# 0.200000,9.000000,0.500000
# called
# [ 0.82923319  0.82923337]
# 0.200000,9.000000,0.600000
# called
# [ 0.83058975  0.83058993]
# 0.200000,9.000000,0.700000
# called
# [ 0.83190274  0.83190291]
# 0.200000,9.000000,0.800000
# called
# [ 0.83317499  0.83317516]
# 0.300000,6.000000,0.100000
# called
# [ nan  nan]
# 0.300000,6.000000,0.200000
# called
# [ 0.7111162   0.71111634]
# 0.300000,6.000000,0.300000
# called
# [ 0.72843154  0.72843169]
# 0.300000,6.000000,0.400000
# called
# [ 0.73688091  0.73688106]
# 0.300000,6.000000,0.500000
# called
# [ 0.74305546  0.74305561]
# 0.300000,6.000000,0.600000
# called
# [ 0.74816505  0.7481652 ]
# 0.300000,6.000000,0.700000
# called
# [ 0.75264163  0.75264179]
# 0.300000,6.000000,0.800000
# called
# [ 0.75668548  0.75668564]
# 0.300000,7.000000,0.100000
# called
# [ 0.76816466  0.76816482]
# 0.300000,7.000000,0.200000
# called
# [ 0.77347101  0.77347117]
# 0.300000,7.000000,0.300000
# called
# [ 0.77770896  0.77770912]
# 0.300000,7.000000,0.400000
# called
# [ 0.78134474  0.7813449 ]
# 0.300000,7.000000,0.500000
# called
# [ 0.7845879   0.78458806]
# 0.300000,7.000000,0.600000
# called
# [ 0.78754923  0.78754939]
# 0.300000,7.000000,0.700000
# called
# [ 0.7902939   0.79029406]
# 0.300000,7.000000,0.800000
# called
# [ 0.79286338  0.79286354]
# 0.300000,8.000000,0.100000
# called
# [ 0.80475864  0.80475881]
# 0.300000,8.000000,0.200000
# called
# [ 0.80741507  0.80741523]
# 0.300000,8.000000,0.300000
# called
# [ 0.80982569  0.80982586]
# 0.300000,8.000000,0.400000
# called
# [ 0.81205118  0.81205135]
# 0.300000,8.000000,0.500000
# called
# [ 0.81413002  0.81413019]
# 0.300000,8.000000,0.600000
# called
# [ 0.81608807  0.81608824]
# 0.300000,8.000000,0.700000
# called
# [ 0.81794354  0.81794371]
# 0.300000,8.000000,0.800000
# called
# [ 0.81970975  0.81970992]
# 0.300000,9.000000,0.100000
# called
# [ 0.83012796  0.83012813]
# 0.300000,9.000000,0.200000
# called
# [ 0.83183974  0.83183991]
# 0.300000,9.000000,0.300000
# called
# [ 0.83345051  0.83345068]
# 0.300000,9.000000,0.400000
# called
# [ 0.83497644  0.83497661]
# 0.300000,9.000000,0.500000
# called
# [ 0.83642933  0.83642951]
# 0.300000,9.000000,0.600000
# called
# [ 0.83781809  0.83781827]
# 0.300000,9.000000,0.700000
# called
# [ 0.8391496   0.83914978]
# 0.300000,9.000000,0.800000
# called
# [ 0.84042929  0.84042947]
# 0.400000,6.000000,0.100000
# called
# [ nan  nan]
# 0.400000,6.000000,0.200000
# called
# [ nan  nan]
# 0.400000,6.000000,0.300000
# called
# [ 0.73409441  0.73409457]
# 0.400000,6.000000,0.400000
# called
# [ 0.74708976  0.74708991]
# 0.400000,6.000000,0.500000
# called
# [ 0.75508109  0.75508125]
# 0.400000,6.000000,0.600000
# called
# [ 0.7611363   0.76113646]
# 0.400000,6.000000,0.700000
# called
# [ 0.76615192  0.76615208]
# 0.400000,6.000000,0.800000
# called
# [ 0.77050845  0.77050861]
# 0.400000,7.000000,0.100000
# called
# [ 0.77580819  0.77580836]
# 0.400000,7.000000,0.200000
# called
# [ 0.78333388  0.78333404]
# 0.400000,7.000000,0.300000
# called
# [ 0.78870946  0.78870962]
# 0.400000,7.000000,0.400000
# called
# [ 0.79301384  0.79301401]
# 0.400000,7.000000,0.500000
# called
# [ 0.79667333  0.7966735 ]
# 0.400000,7.000000,0.600000
# called
# [ 0.79989796  0.79989813]
# 0.400000,7.000000,0.700000
# called
# [ 0.80280574  0.80280591]
# 0.400000,7.000000,0.800000
# called
# [ 0.80546922  0.80546939]
# 0.400000,8.000000,0.100000
# called
# [ 0.81493455  0.81493472]
# 0.400000,8.000000,0.200000
# called
# [ 0.81805393  0.8180541 ]
# 0.400000,8.000000,0.300000
# called
# [ 0.82077355  0.82077372]
# 0.400000,8.000000,0.400000
# called
# [ 0.8232073   0.82320747]
# 0.400000,8.000000,0.500000
# called
# [ 0.82542469  0.82542486]
# 0.400000,8.000000,0.600000
# called
# [ 0.8274711   0.82747127]
# 0.400000,8.000000,0.700000
# called
# [ 0.82937767  0.82937785]
# 0.400000,8.000000,0.800000
# called
# [ 0.83116669  0.83116686]
# 0.400000,9.000000,0.100000
# called
# [ 0.84014241  0.84014258]
# 0.400000,9.000000,0.200000
# called
# [ 0.84201501  0.84201519]
# 0.400000,9.000000,0.300000
# called
# [ 0.84373841  0.84373859]
# 0.400000,9.000000,0.400000
# called
# [ 0.8453409   0.84534108]
# 0.400000,9.000000,0.500000
# called
# [ 0.84684273  0.8468429 ]
# 0.400000,9.000000,0.600000
# called
# [ 0.84825884  0.84825902]
# 0.400000,9.000000,0.700000
# called
# [ 0.8496006   0.84960078]
# 0.400000,9.000000,0.800000
# called
# [ 0.85087685  0.85087702]
# 0.500000,6.000000,0.100000
# called
# [ nan  nan]
# 0.500000,6.000000,0.200000
# called
# [ nan  nan]
# 0.500000,6.000000,0.300000
# called
# [ 0.73893475  0.7389349 ]
# 0.500000,6.000000,0.400000
# called
# [ 0.76146644  0.7614666 ]
# 0.500000,6.000000,0.500000
# called
# [ 0.77199963  0.7719998 ]
# 0.500000,6.000000,0.600000
# called
# [ 0.77919812  0.77919828]
# 0.500000,6.000000,0.700000
# called
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-dbb6e98b28d8> in <module>()
#       4         for a in np.arange(0.1,0.9,0.1):
#       5             print('%f,%f,%f'%(e,p,a))
# ----> 6             print(np.array(getfreq_dt_fromepa(e,p,a))/np.array(getfreq_fromepa(e,p,a)))
#
# <ipython-input-5-aa4d221dd63a> in getfreq_fromepa(e, p, spin)
#      17     #reference: https://arxiv.org/pdf/gr-qc/0202090.pdf (39)-(42)
#      18     myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*np.power(1+e*np.cos(chi),2)
# ---> 19     myH=1-2/p*(1+e*cos(chi))+(spin**2)/(p**2)*np.power(1+e*np.cos(chi),2)
#      20     myG=Lz-2*(Lz-spin*E)/p*(1+e*np.cos(chi))
#      21
#
# KeyboardInterrupt:

# %%
#在误差范围内，结果是相当OK的，我觉得可以把对t的角频率与对tau的的角频率看做是只差一个比例

# %%
#为了速度，重新写对tau角频率（用库函数的积分不用np.sum了。。。）

# %%
def myY_int(chi,e,p,spin):
    rmax=p/(1-e)
    rmin=p/(1+e)
    invgmin=metric_KRZ_inverse(spin,0,rmin,np.pi/2)
    invgmax=metric_KRZ_inverse(spin,0,rmax,np.pi/2)

    EoverL = ((invgmax[3][0] - invgmin[3][0]) + sqrt((invgmax[3][0] - invgmin[3][0]) *(invgmax[3][0] - invgmin[3][0]) - (invgmax[0][0] - invgmin[0][0])*(invgmax[3][3] - invgmin[3][3]))) / ( invgmax[0][0]-invgmin[0][0] );
    Lz = sqrt( (invgmax[3][0]-invgmin[3][0]) / ( EoverL*EoverL*( invgmin[3][0]*invgmax[0][0] - invgmax[3][0]*invgmin[0][0] )+ ( invgmin[3][0]*invgmax[3][3]- invgmax[3][0]*invgmin[3][3] )  )   );
    E=Lz*EoverL
    Q=0
    myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*np.power(1+e*np.cos(chi),2)
    myH=1-2/p*(1+e*cos(chi))+(spin**2)/(p**2)*np.power(1+e*np.cos(chi),2)
    myG=Lz-2*(Lz-spin*E)/p*(1+e*np.cos(chi))

    myY_=p**2*np.multiply( np.power(1+e*np.cos(chi),-2) ,np.power(myJ,-0.5) )
    return myY_

# %%
def myZ_int(chi,e,p,spin):
    rmax=p/(1-e)
    rmin=p/(1+e)
    invgmin=metric_KRZ_inverse(spin,0,rmin,np.pi/2)
    invgmax=metric_KRZ_inverse(spin,0,rmax,np.pi/2)

    EoverL = ((invgmax[3][0] - invgmin[3][0]) + sqrt((invgmax[3][0] - invgmin[3][0]) *(invgmax[3][0] - invgmin[3][0]) - (invgmax[0][0] - invgmin[0][0])*(invgmax[3][3] - invgmin[3][3]))) / ( invgmax[0][0]-invgmin[0][0] );
    Lz = sqrt( (invgmax[3][0]-invgmin[3][0]) / ( EoverL*EoverL*( invgmin[3][0]*invgmax[0][0] - invgmax[3][0]*invgmin[0][0] )+ ( invgmin[3][0]*invgmax[3][3]- invgmax[3][0]*invgmin[3][3] )  )   );
    E=Lz*EoverL
    Q=0
    myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*np.power(1+e*np.cos(chi),2)
    myH=1-2/p*(1+e*cos(chi))+(spin**2)/(p**2)*np.power(1+e*np.cos(chi),2)
    myG=Lz-2*(Lz-spin*E)/p*(1+e*np.cos(chi))
    myZ_=np.multiply(myG, np.multiply( np.power(myH,-1),np.power(myJ,-0.5) ) )
    return myZ_

# %%
def getfreq_dtau_fromepa(e,p,spin):
    myY,err=scipy.integrate.quad(myY_int,0,np.pi,args=(e,p,spin))
    myZ,err=scipy.integrate.quad(myZ_int,0,np.pi,args=(e,p,spin))
    myomgr=np.pi*p/(1-e**2)/myY
    myomgphi=myZ/myY
    return myomgr,myomgphi

# %%
e=0.5;p=6.5;a=0.5
for e in np.arange(0.1,0.9,0.1):
    for p in np.arange(6,10,1):
        for a in np.arange(0.1,0.9,0.1):
            print('%f,%f,%f'%(e,p,a))
            print(np.array(getfreq_fromepa_npsum(e,p,a))/np.array(getfreq_dtau_fromepa(e,p,a)))
# Out:
# 0.100000,6.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.100000,6.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.100000,6.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.100000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.100000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.100000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.100000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.100000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.100000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.100000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.100000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.200000,6.000000,0.100000
# called
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in power
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in power
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in power
#   from ipykernel import kernelapp as app
# D:\ProgramFiles\lib\site-packages\scipy\integrate\quadpack.py:364: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg, IntegrationWarning)
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in power
# [ nan  nan]
# 0.200000,6.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.200000,6.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.200000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.200000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.200000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.200000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.200000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.200000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.200000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.200000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.300000,6.000000,0.100000
# called
# [ nan  nan]
# 0.300000,6.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.300000,6.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.300000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.300000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.300000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.300000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.300000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.300000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.300000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.300000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.400000,6.000000,0.100000
# called
# [ nan  nan]
# 0.400000,6.000000,0.200000
# called
# [ nan  nan]
# 0.400000,6.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.400000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.400000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.400000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.400000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.400000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.400000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.400000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.400000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.500000,6.000000,0.100000
# called
# [ nan  nan]
# 0.500000,6.000000,0.200000
# called
# [ nan  nan]
# 0.500000,6.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.500000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.500000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.500000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.500000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.500000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.500000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.500000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.500000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.600000,6.000000,0.100000
# called
# [ nan  nan]
# 0.600000,6.000000,0.200000
# called
# [ nan  nan]
# 0.600000,6.000000,0.300000
# called
# [ nan  nan]
# 0.600000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.600000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.600000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.600000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.600000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.600000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.600000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.600000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.700000,6.000000,0.100000
# called
# [ nan  nan]
# 0.700000,6.000000,0.200000
# called
# [ nan  nan]
# 0.700000,6.000000,0.300000
# called
# [ nan  nan]
# 0.700000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.700000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.700000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.700000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.700000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.700000,7.000000,0.100000
# called
# [ nan  nan]
# 0.700000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.700000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.700000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.700000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.700000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.700000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.700000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.700000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.700000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.800000,6.000000,0.100000
# called
# [ nan  nan]
# 0.800000,6.000000,0.200000
# called
# [ nan  nan]
# 0.800000,6.000000,0.300000
# called
# [ nan  nan]
# 0.800000,6.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.800000,6.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.800000,6.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.800000,6.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.800000,6.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.800000,7.000000,0.100000
# called
# [ nan  nan]
# 0.800000,7.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.800000,7.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.800000,7.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.800000,7.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.800000,7.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.800000,7.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.800000,7.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.800000,8.000000,0.800000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.100000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.200000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.300000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.400000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.500000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.600000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.700000
# called
# [ 1.00000021  1.        ]
# 0.800000,9.000000,0.800000
# called
# [ 1.00000021  1.        ]

# %%
#OK, 新的积分的方法也没问题

# %%
#那接下来我们来搞三维的角频率了

# %%
from KRZmetric import *
import numpy as np
from scipy.optimize import fsolve
import scipy

e=0.5
p=6
spin=0.5
iota=0

# %%
th_min=np.pi/2-iota

# %%
def Vr(E,L,e,p,iota,spin):
    #Vr at apestron and periastron, assuming Vth(theta_min)=0, i.e.Q=cos(theta)*(a**2*(1-E**2)+L**2/(sin(theta)*sin(theta)));
    a=spin
    ra=p/(1-e);
    rp=p/(1+e);
    theta=np.pi/2-iota;

    Del=ra**2-2*ra+a**2;
    P=E*(ra**2+a**2)-a*L;
    Q=np.cos(theta)**2*(a**2*(1-E**2)+L**2/(np.sin(theta)*np.sin(theta)));
    vra=P**2-Del*(ra**2+(L-a*E)**2+Q);

    Delp=rp**2-2*rp+a**2;
    Pp=E*(rp**2+a**2)-a*L;
    vrp=Pp**2-Delp*(rp**2+(L-a*E)**2+Q);
    return vra,vrp

# %%
def myfunc(x):
    E=x[0]
    L=x[1]
    V= Vr(E,L,e,p,iota,spin)
    print('E:%f, L:%f, V: %f, %f'%(E,L,V[0],V[1]))
    return V

# %%
E,L=fsolve(myfunc,[0.9,3.0])
# Out:
# E:0.900000, L:3.000000, V: -1630.620000, -13.380000
# E:0.900000, L:3.000000, V: -1630.620000, -13.380000
# E:0.900000, L:3.000000, V: -1630.620000, -13.380000
# E:0.900000, L:3.000000, V: -1630.619499, -13.379994
# E:0.900000, L:3.000000, V: -1630.620033, -13.380002
# E:0.946331, L:3.133295, V: 42.321429, 0.370859
# E:0.945169, L:3.130419, V: -1.050841, -0.010220
# E:0.945197, L:3.130467, V: 0.000067, 0.000044
# E:0.945197, L:3.130468, V: -0.000031, -0.000002
# E:0.945197, L:3.130468, V: 0.000001, 0.000000

# %%
Q=np.cos(th_min)**2*(spin**2*(1-E**2)+L**2/(np.sin(th_min)*np.sin(th_min)))

# %%
E,L,Q
# Out:
# (0.9451965608264854, 3.1304678816433684, 3.6843398860380572e-32)

# %%
Lz=L

# %%
#z_min=np.cos(th_min)

#th_max=np.pi-th_min
#z_max=np.cos(th_max)
#k=z_min**2/z_max**2

#这里有问题，仔细看文章里的z_plus, z_minus是are the two roots of the equation Θ(z) = 0 when substituting cosθ = z in Θ
z_plus=np.sqrt(( Q+Lz**2+spin**2*(1-E**2) + np.sqrt( (Q+Lz**2+spin**2*(1-E**2))**2 - 4*Q*spin**2*(1-E**2) ) )/(2*spin**2*(1-E**2)))
z_minus=np.sqrt(( Q+Lz**2+spin**2*(1-E**2) - np.sqrt( (Q+Lz**2+spin**2*(1-E**2))**2 - 4*Q*spin**2*(1-E**2) ) )/(2*spin**2*(1-E**2)))
if np.abs(iota-0.0)<1e-20:
    z_minus=0.0

# %%
z_plus,z_minus,np.cos(th_min) #z_minus正是cos(th_min)
# Out:
# (19.201861384430998, 0.0, 6.123233995736766e-17)

# %%
k=(z_minus/z_plus)**2

# %%
beta=np.sqrt(spin**2*(1-E**2))

# %%
def K_int(psi,k):
    return 1.0/np.sqrt(1-k*np.sin(psi)**2)

# %%
def E_int(psi,k):
    return np.sqrt(1-k*np.sin(psi)**2)

# %%
def PI_int(psi,z_minus,k):
    return 1.0/( (1-z_minus**2*np.sin(psi)**2)*np.sqrt(1-k*np.sin(psi)**2) )

# %%
K,err=scipy.integrate.quad(K_int,0,np.pi/2,args=(k))

E_k,err=scipy.integrate.quad(E_int,0,np.pi/2,args=(k))

PI,err=scipy.integrate.quad(PI_int,0,np.pi/2,args=(z_minus,k))

# %%
K,E_k,PI
# Out:
# (1.5707963267948966, 1.5707963267948966, 1.5707963267948966)

# %%
def Ytilt_int(chi,e,p,E,Lz,Q,spin):
    
    myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*(1+e*np.cos(chi))**2
    myH=1-2/p*(1+e*cos(chi))+(spin**2)/(p**2)*(1+e*np.cos(chi))**2
    myG=Lz-2*(Lz-spin*E)/p*(1+e*np.cos(chi))

    myY_=p**2 /(1+e*np.cos(chi))**2/ np.sqrt(myJ) 
    return myY_

def Ztilt_int(chi,e,p,E,Lz,Q,spin):
    
    myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*np.power(1+e*np.cos(chi),2)
    myH=1-2/p*(1+e*cos(chi))+(spin**2)/(p**2)*np.power(1+e*np.cos(chi),2)
    myG=Lz-2*(Lz-spin*E)/p*(1+e*np.cos(chi))
    myZ_=np.multiply(myG, np.multiply( np.power(myH,-1),np.power(myJ,-0.5) ) )
    return myZ_

def Xtilt_int(chi,e,p,E,Lz,Q,spin):
    
    myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*np.power(1+e*np.cos(chi),2)
    myX_=1/np.sqrt(myJ)
    return myX_

# %%
Ytilt,err=scipy.integrate.quad(Ytilt_int,0,np.pi,args=(e,p,E,Lz,Q,spin))

Ztilt,err=scipy.integrate.quad(Ztilt_int,0,np.pi,args=(e,p,E,Lz,Q,spin))

Xtilt,err=scipy.integrate.quad(Xtilt_int,0,np.pi,args=(e,p,E,Lz,Q,spin))

LAMBDA=(Ytilt+spin**2 * z_plus**2*Xtilt)*K-spin**2 *z_plus**2 *Xtilt*E_k

omgr=np.pi*p*K/(1-e**2)/LAMBDA

omgth=np.pi*beta*z_plus*Xtilt/2/LAMBDA

omgphi=( (Ztilt-Lz*Xtilt)*K + Lz*Xtilt*PI )/LAMBDA

# %%
omgr,omgth,omgphi
# Out:
# (0.032302396289115035, 0.063238066394409792, 0.067772866008525973)

# %%
getfreq_dtau_fromepa(e,p,spin)
# Out:
# (0.032302396323644504, 0.0677728659479056)

# %%
#对tau的角频率到这就算完了其实
#下面和getfreq_dtau_fromepa在二维的情况对比一下
#貌似和对t的角频率差的就是那个小gamma?

# %%
getfreq_dt_fromepa(e,p,spin)
# Out:
# (0.02493744335359075, 0.05232063864714793)

# %%
def Wtilt_int(chi,e,p,E,Lz,Q,spin):
    myF=E+spin**2*E/p**2*(1+e*np.cos(chi))**2 - 2*spin*(Lz-spin*E)*(1+e*np.cos(chi))**3 / p**3 
    myJ=(1-E**2)*(1-e**2)+2*(1-E**2-(1-e**2)/p)*(1+e*np.cos(chi))+((1-E**2)*(3+e**2)/(1-e**2) -4/p +(spin**2*(1-E**2)+Lz**2+Q)*(1-e**2)/p**2 )*(1+e*np.cos(chi))**2
    myH=1-2/p*(1+e*cos(chi))+(spin**2)/(p**2)*(1+e*np.cos(chi))**2
    myW_=p**2*myF/( (1+e*np.cos(chi))**2 * myH * np.sqrt(myJ) )
    return myW_

# %%
Wtilt,err=scipy.integrate.quad(Wtilt_int,0,np.pi,args=(e,p,E,Lz,Q,spin))

# %%
gamma=( (Wtilt+spin**2*z_plus**2*E*Xtilt)*K - spin**2*z_plus**2*E*Xtilt*E_k )/LAMBDA

# %%
gamma
# Out:
# 1.2953371310777733

# %%
omgr/gamma,omgphi/gamma
# Out:
# (0.024937443321985317, 0.052320638683565096)

# %%
getfreq_dt_fromepa(e,p,spin)
# Out:
# (0.02493744335359075, 0.05232063864714793)

# %%
#OK,没问题，写成函数吧

# %%
#写好了，重启kernel，检验一下二维符不符合

# %%
from KRZmetric import *

# %%
import numpy as np

# %%
e=0.5;p=6.5;a=0.5
for e in np.arange(0.1,0.9,0.1):
    for p in np.arange(6,10,1):
        for a in np.arange(0.1,0.9,0.1):
            print('%f,%f,%f'%(e,p,a))
            print(np.array(getfreq_dt_fromepa(e,p,a)) - np.array ([freq3_dt(e,p,0,a)[0],freq3_dt(e,p,0,a)[2]]) )
# Out:
# 0.100000,6.000000,0.100000
# [ -2.37122821e-13   4.25076641e-14]
# 0.100000,6.000000,0.200000
# [ -5.01335085e-15  -1.66533454e-16]
# 0.100000,6.000000,0.300000
# [ -9.78384040e-16   2.49800181e-16]
# 0.100000,6.000000,0.400000
# [  5.03565939e-13   1.03944631e-13]
# 0.100000,6.000000,0.500000
# [  7.67649833e-14   2.68535194e-14]
# 0.100000,6.000000,0.600000
# [  1.59663949e-14   5.55111512e-17]
# 0.100000,6.000000,0.700000
# [ -2.12836693e-13  -4.82530682e-14]
# 0.100000,6.000000,0.800000
# [ -1.94712302e-13  -7.20118409e-14]
# 0.100000,7.000000,0.100000
# [ -2.23446261e-13  -3.33899575e-14]
# 0.100000,7.000000,0.200000
# [ -1.72674375e-14  -3.24740235e-15]
# 0.100000,7.000000,0.300000
# [  2.25514052e-16   5.13478149e-16]
# 0.100000,7.000000,0.400000
# [ -2.70616862e-16   1.38777878e-17]
# 0.100000,7.000000,0.500000
# [ -2.49800181e-16   4.16333634e-17]
# 0.100000,7.000000,0.600000
# [ -3.48955587e-12  -1.26501587e-12]
# 0.100000,7.000000,0.700000
# [  3.90965038e-13   1.86017868e-13]
# 0.100000,7.000000,0.800000
# [ -1.19360147e-11  -1.80261223e-11]
# 0.100000,8.000000,0.100000
# [ -7.47284179e-13  -1.72688253e-13]
# 0.100000,8.000000,0.200000
# [ -1.44193685e-13  -3.65957264e-14]
# 0.100000,8.000000,0.300000
# [ -4.72538675e-15  -1.72778458e-15]
# 0.100000,8.000000,0.400000
# [  9.07954267e-15   2.76861867e-15]
# 0.100000,8.000000,0.500000
# [  4.94396191e-15   1.15879528e-15]
# 0.100000,8.000000,0.600000
# [  1.28716482e-15   0.00000000e+00]
# 0.100000,8.000000,0.700000
# [  1.14144805e-15  -1.73472348e-16]
# 0.100000,8.000000,0.800000
# [ -5.06539255e-16   5.55111512e-17]
# 0.100000,9.000000,0.100000
# [ -2.81492885e-12  -8.00123856e-13]
# 0.100000,9.000000,0.200000
# [ -9.54517715e-13  -2.86964896e-13]
# 0.100000,9.000000,0.300000
# [ -2.38670195e-13  -7.60086438e-14]
# 0.100000,9.000000,0.400000
# [ -1.16295862e-14  -4.19803081e-15]
# 0.100000,9.000000,0.500000
# [  3.41601747e-14   1.22402088e-14]
# 0.100000,9.000000,0.600000
# [  2.79463952e-14   1.05263021e-14]
# 0.100000,9.000000,0.700000
# [  1.50157664e-14   5.83560977e-15]
# 0.100000,9.000000,0.800000
# [  5.29437605e-15   2.31065167e-15]
# 0.200000,6.000000,0.100000
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:688: RuntimeWarning: invalid value encountered in sqrt
#   Tr_=2*Vt/J/np.sqrt(Vr)
# D:\ProgramFiles\lib\site-packages\scipy\integrate\quadpack.py:364: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg, IntegrationWarning)
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:715: RuntimeWarning: invalid value encountered in sqrt
#   Dp_=2*Vphi/J/np.sqrt(Vr)
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:848: RuntimeWarning: invalid value encountered in sqrt
#   myY_=p**2 /(1+e*np.cos(chi))**2/ np.sqrt(myJ)
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:856: RuntimeWarning: invalid value encountered in power
#   myZ_=np.multiply(myG, np.multiply( np.power(myH,-1),np.power(myJ,-0.5) ) )
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:839: RuntimeWarning: invalid value encountered in sqrt
#   myX_=1/np.sqrt(myJ)
# C:\Users\HP\Documents\GitHub\KRZwave\KRZmetric.py:833: RuntimeWarning: invalid value encountered in sqrt
#   myW_=p**2*myF/( (1+e*np.cos(chi))**2 * myH * np.sqrt(myJ) )
# [ nan  nan]
# 0.200000,6.000000,0.200000
# [  1.00613962e-15  -3.74700271e-16]
# 0.200000,6.000000,0.300000
# [  7.28583860e-17   4.16333634e-17]
# 0.200000,6.000000,0.400000
# [  7.85305848e-13   5.39568390e-14]
# 0.200000,6.000000,0.500000
# [  2.45206633e-13   5.87169202e-14]
# 0.200000,6.000000,0.600000
# [  5.97764893e-13  -1.43718371e-13]
# 0.200000,6.000000,0.700000
# [ -2.99947567e-13  -3.56936702e-14]
# 0.200000,6.000000,0.800000
# [ -6.14508444e-13  -1.39020739e-13]
# 0.200000,7.000000,0.100000
# [ -1.24268651e-13   2.01921813e-15]
# 0.200000,7.000000,0.200000
# [  7.01522174e-15   6.93889390e-16]
# 0.200000,7.000000,0.300000
# [  3.92394450e-15   9.08995101e-16]
# 0.200000,7.000000,0.400000
# [ -3.46944695e-17   1.66533454e-16]
# 0.200000,7.000000,0.500000
# [  2.49800181e-16  -7.63278329e-17]
# 0.200000,7.000000,0.600000
# [ -5.62424066e-12  -1.78323328e-12]
# 0.200000,7.000000,0.700000
# [  9.43828349e-13   4.13821755e-13]
# 0.200000,7.000000,0.800000
# [  1.67713066e-13   2.02539374e-13]
# 0.200000,8.000000,0.100000
# [ -3.37094935e-13  -4.93424746e-14]
# 0.200000,8.000000,0.200000
# [  1.00822128e-14   1.81105131e-15]
# 0.200000,8.000000,0.300000
# [  4.07243683e-14   8.90260088e-15]
# 0.200000,8.000000,0.400000
# [  2.00638117e-14   5.05845366e-15]
# 0.200000,8.000000,0.500000
# [  4.75661177e-15   1.70002901e-15]
# 0.200000,8.000000,0.600000
# [  4.47558657e-16   1.17961196e-16]
# 0.200000,8.000000,0.700000
# [  6.93889390e-17  -1.04083409e-16]
# 0.200000,8.000000,0.800000
# [ -1.94289029e-16   1.17961196e-16]
# 0.200000,9.000000,0.100000
# [ -1.31724492e-12  -3.04534176e-13]
# 0.200000,9.000000,0.200000
# [ -1.89171595e-13  -4.94396191e-14]
# 0.200000,9.000000,0.300000
# [  1.10859238e-13   3.03715386e-14]
# 0.200000,9.000000,0.400000
# [  1.30354061e-13   3.91908728e-14]
# 0.200000,9.000000,0.500000
# [  8.50500226e-14   2.75890422e-14]
# 0.200000,9.000000,0.600000
# [  4.31113478e-14   1.49741330e-14]
# 0.200000,9.000000,0.700000
# [  1.74062154e-14   6.33521013e-15]
# 0.200000,9.000000,0.800000
# [  4.13905021e-15   1.87350135e-15]
# 0.300000,6.000000,0.100000
# [ nan  nan]
# 0.300000,6.000000,0.200000
# [  2.17083296e-14  -2.29677388e-14]
# 0.300000,6.000000,0.300000
# [  7.49400542e-16  -4.30211422e-16]
# 0.300000,6.000000,0.400000
# [  1.70060147e-12  -3.87294363e-13]
# 0.300000,6.000000,0.500000
# [  1.03681647e-12  -1.84990911e-14]
# 0.300000,6.000000,0.600000
# [  2.76780682e-12  -3.26133565e-12]
# 0.300000,6.000000,0.700000
# [ -1.03901533e-10   9.00194502e-12]
# 0.300000,6.000000,0.800000
# [ -1.33278111e-12  -3.80806497e-14]
# 0.300000,7.000000,0.100000
# [  5.61703462e-14  -2.06848427e-14]
# 0.300000,7.000000,0.200000
# [  4.83502127e-14  -9.83935156e-15]
# 0.300000,7.000000,0.300000
# [  9.70057368e-15  -7.77156117e-16]
# 0.300000,7.000000,0.400000
# [  8.67361738e-17   1.38777878e-17]
# 0.300000,7.000000,0.500000
# [  2.42861287e-17  -6.93889390e-17]
# 0.300000,7.000000,0.600000
# [ -1.13007104e-11  -1.97082628e-12]
# 0.300000,7.000000,0.700000
# [  2.73187029e-12   8.25742252e-13]
# 0.300000,7.000000,0.800000
# [  5.22359933e-13   4.31349401e-13]
# 0.300000,8.000000,0.100000
# [  2.10748086e-13  -1.37112544e-14]
# 0.300000,8.000000,0.200000
# [  1.96658662e-13   1.17961196e-15]
# 0.300000,8.000000,0.300000
# [  9.17044218e-14   6.02295991e-15]
# 0.300000,8.000000,0.400000
# [  2.93862157e-14   3.51108032e-15]
# 0.300000,8.000000,0.500000
# [  5.14865928e-15   8.32667268e-16]
# 0.300000,8.000000,0.600000
# [ -3.50414142e-16   2.77555756e-17]
# 0.300000,8.000000,0.700000
# [ -1.90819582e-16  -1.80411242e-16]
# 0.300000,8.000000,0.800000
# [  3.15719673e-16  -4.85722573e-17]
# 0.300000,9.000000,0.100000
# [  4.66394284e-13   3.30013794e-14]
# 0.300000,9.000000,0.200000
# [  6.27286417e-13   7.37049310e-14]
# 0.300000,9.000000,0.300000
# [  4.44054515e-13   6.97220059e-14]
# 0.300000,9.000000,0.400000
# [  2.50993670e-13   4.82322515e-14]
# 0.300000,9.000000,0.500000
# [  1.20903287e-13   2.72074030e-14]
# 0.300000,9.000000,0.600000
# [  4.86242990e-14   1.22124533e-14]
# 0.300000,9.000000,0.700000
# [  1.41171796e-14   3.87884169e-15]
# 0.300000,9.000000,0.800000
# [  1.70002901e-15   4.51028104e-16]
# 0.400000,6.000000,0.100000
# [ nan  nan]
# 0.400000,6.000000,0.200000
# [ nan  nan]
# 0.400000,6.000000,0.300000
# [  7.91033905e-16  -8.46545056e-16]
# 0.400000,6.000000,0.400000
# [  2.60208521e-16  -2.35922393e-16]
# 0.400000,6.000000,0.500000
# [  5.53802143e-12  -2.51575150e-12]
# 0.400000,6.000000,0.600000
# [  2.00402195e-13   8.74925132e-14]
# 0.400000,6.000000,0.700000
# [ -7.05158848e-12   3.02052133e-12]
# 0.400000,6.000000,0.800000
# [ -2.59085114e-12   6.99738878e-13]
# 0.400000,7.000000,0.100000
# [  4.91190422e-13  -4.77756723e-13]
# 0.400000,7.000000,0.200000
# [  1.24136812e-13  -8.42381720e-14]
# 0.400000,7.000000,0.300000
# [  1.55570001e-14  -7.34828864e-15]
# 0.400000,7.000000,0.400000
# [  6.93889390e-17  -2.28983499e-16]
# 0.400000,7.000000,0.500000
# [ -1.24900090e-16   6.93889390e-18]
# 0.400000,7.000000,0.600000
# [ -2.67126911e-11   2.87742746e-12]
# 0.400000,7.000000,0.700000
# [  8.77530687e-12   2.56655808e-13]
# 0.400000,7.000000,0.800000
# [  1.84361554e-12   7.17384485e-13]
# 0.400000,8.000000,0.100000
# [  9.89465454e-13  -4.42951231e-13]
# 0.400000,8.000000,0.200000
# [  4.29389163e-13  -1.42302836e-13]
# 0.400000,8.000000,0.300000
# [  1.45588402e-13  -3.46042639e-14]
# 0.400000,8.000000,0.400000
# [  3.27897431e-14  -5.15559817e-15]
# 0.400000,8.000000,0.500000
# [  2.18922103e-15  -3.53883589e-16]
# 0.400000,8.000000,0.600000
# [ -1.36696210e-15   8.32667268e-17]
# 0.400000,8.000000,0.700000
# [ -1.04083409e-17  -1.45716772e-16]
# 0.400000,8.000000,0.800000
# [  3.98986399e-16   7.63278329e-17]
# 0.400000,9.000000,0.100000
# [  2.42685733e-12  -5.50830215e-13]
# 0.400000,9.000000,0.200000
# [  1.42083567e-12  -2.25330171e-13]
# 0.400000,9.000000,0.300000
# [  7.33999667e-13  -7.29069582e-14]
# 0.400000,9.000000,0.400000
# [  3.35412254e-13  -1.57616975e-14]
# 0.400000,9.000000,0.500000
# [  1.28241168e-13  -9.02056208e-17]
# 0.400000,9.000000,0.600000
# [  3.48124307e-14   1.53696500e-15]
# 0.400000,9.000000,0.700000
# [  3.10168558e-15   2.42861287e-16]
# 0.400000,9.000000,0.800000
# [ -2.93515212e-15  -3.22658567e-16]
# 0.500000,6.000000,0.100000
# [ nan  nan]
# 0.500000,6.000000,0.200000
# [ nan  nan]
# 0.500000,6.000000,0.300000
# [  5.27355937e-16  -1.19348975e-15]
# 0.500000,6.000000,0.400000
# [ -8.60422844e-16   1.37390099e-15]
# 0.500000,6.000000,0.500000
# [  3.16054335e-11  -3.64171679e-11]
# 0.500000,6.000000,0.600000
# [  3.15572221e-12  -2.32759645e-12]
# 0.500000,6.000000,0.700000
# [ -2.72351586e-15   2.67841305e-15]
# 0.500000,6.000000,0.800000
# [ -2.81191737e-12   2.07532602e-12]
# 0.500000,7.000000,0.100000
# [  1.80866780e-12  -3.57315566e-12]
# 0.500000,7.000000,0.200000
# [  2.69319289e-13  -3.95607158e-13]
# 0.500000,7.000000,0.300000
# [  1.60461922e-14  -1.84852134e-14]
# 0.500000,7.000000,0.400000
# [ -2.54310462e-15   2.30371278e-15]
# 0.500000,7.000000,0.500000
# [  7.63278329e-17  -2.77555756e-17]
# 0.500000,7.000000,0.600000
# [ -6.91937271e-11   4.13714479e-11]
# 0.500000,7.000000,0.700000
# [  2.81870499e-11  -1.24412425e-11]
# 0.500000,7.000000,0.800000
# [  6.61563859e-12  -1.14093457e-12]
# 0.500000,8.000000,0.100000
# [  2.16837312e-12  -2.38630643e-12]
# 0.500000,8.000000,0.200000
# [  7.16041809e-13  -6.55885068e-13]
# 0.500000,8.000000,0.300000
# [  2.41820453e-15  -1.97064587e-15]
# 0.500000,8.000000,0.400000
# [  1.58796587e-14  -1.02556852e-14]
# 0.500000,8.000000,0.500000
# [ -5.19376209e-15   2.81719092e-15]
# 0.500000,8.000000,0.600000
# [ -2.40779618e-15   1.16573418e-15]
# 0.500000,8.000000,0.700000
# [  4.82253126e-16  -1.66533454e-16]
# 0.500000,8.000000,0.800000
# [ -8.90738108e-11   2.58413881e-11]
# 0.500000,9.000000,0.100000
# [  4.53298163e-12  -3.43738926e-12]
# 0.500000,9.000000,0.200000
# [  2.16419591e-12  -1.41225573e-12]
# 0.500000,9.000000,0.300000
# [  9.14799486e-13  -5.14244897e-13]
# 0.500000,9.000000,0.400000
# [  4.24660307e-15  -2.07472928e-15]
# 0.500000,9.000000,0.500000
# [  6.69256317e-14  -2.78249646e-14]
# 0.500000,9.000000,0.600000
# [ -3.20229954e-15   9.57567359e-16]
# 0.500000,9.000000,0.700000
# [ -1.15497889e-14   3.61863317e-15]
# 0.500000,9.000000,0.800000
# [ -5.82173199e-15   1.42941214e-15]
# 0.600000,6.000000,0.100000
# [ nan  nan]
# 0.600000,6.000000,0.200000
# [ nan  nan]
# 0.600000,6.000000,0.300000
# [ nan  nan]
# 0.600000,6.000000,0.400000
# [  7.11236625e-16  -2.13717932e-15]
# 0.600000,6.000000,0.500000
# [  7.14806721e-11  -1.64528953e-10]
# 0.600000,6.000000,0.600000
# [  2.39992193e-11  -4.43897211e-11]
# 0.600000,6.000000,0.700000
# [ -2.48676080e-13   5.00682829e-13]
# 0.600000,6.000000,0.800000
# [ -6.94479196e-14   1.04742603e-13]
# 0.600000,7.000000,0.100000
# [  7.03715038e-12  -2.58829763e-11]
# 0.600000,7.000000,0.200000
# [  5.97091820e-15  -1.67157954e-14]
# 0.600000,7.000000,0.300000
# [ -1.40963630e-14   3.22450400e-14]
# 0.600000,7.000000,0.400000
# [ -6.62664368e-15   1.28785871e-14]
# 0.600000,7.000000,0.500000
# [  3.87537225e-15  -6.55725474e-15]
# 0.600000,7.000000,0.600000
# [ -1.77203894e-10   2.56656862e-10]
# 0.600000,7.000000,0.700000
# [  7.75517428e-11  -9.70648631e-11]
# 0.600000,7.000000,0.800000
# [  2.18014842e-11  -2.21931432e-11]
# 0.600000,8.000000,0.100000
# [  3.76740132e-12  -8.35618380e-12]
# 0.600000,8.000000,0.200000
# [  1.38240114e-14  -2.66210665e-14]
# 0.600000,8.000000,0.300000
# [  6.33590402e-14  -1.07663878e-13]
# 0.600000,8.000000,0.400000
# [ -2.74363865e-14   4.14390744e-14]
# 0.600000,8.000000,0.500000
# [ -1.12999887e-14   1.52794444e-14]
# 0.600000,8.000000,0.600000
# [  7.25114413e-16  -8.56953397e-16]
# 0.600000,8.000000,0.700000
# [  7.39686090e-15  -8.20871149e-15]
# 0.600000,8.000000,0.800000
# [ -2.85499815e-10   2.81584523e-10]
# 0.600000,9.000000,0.100000
# [  6.48662547e-12  -1.09648193e-11]
# 0.600000,9.000000,0.200000
# [  3.90069921e-14  -5.94663208e-14]
# 0.600000,9.000000,0.300000
# [  6.03619585e-13  -8.36618969e-13]
# 0.600000,9.000000,0.400000
# [  4.16802010e-14  -5.28535549e-14]
# 0.600000,9.000000,0.500000
# [ -5.71383219e-14   6.60166366e-14]
# 0.600000,9.000000,0.600000
# [ -3.89653587e-14   4.14182577e-14]
# 0.600000,9.000000,0.700000
# [ -1.41778950e-14   1.38049294e-14]
# 0.600000,9.000000,0.800000
# [ -6.90419943e-16   7.11236625e-16]
# 0.700000,6.000000,0.100000
# [ nan  nan]
# 0.700000,6.000000,0.200000
# [ nan  nan]
# 0.700000,6.000000,0.300000
# [ nan  nan]
# 0.700000,6.000000,0.400000
# [  4.19681651e-14  -2.32008857e-13]
# 0.700000,6.000000,0.500000
# [ -2.57209226e-10   1.13163431e-09]
# 0.700000,6.000000,0.600000
# [  1.26161488e-10  -4.71194743e-10]
# 0.700000,6.000000,0.700000
# [  3.04128250e-12  -1.01652367e-11]
# 0.700000,6.000000,0.800000
# [ -4.09498824e-14   1.18332427e-13]
# 0.700000,7.000000,0.100000
# [ nan  nan]
# 0.700000,7.000000,0.200000
# [ -1.26553282e-13   6.65002775e-13]
# 0.700000,7.000000,0.300000
# [ -9.20999388e-14   4.04998951e-13]
# 0.700000,7.000000,0.400000
# [  8.05258638e-15  -3.07150139e-14]
# 0.700000,7.000000,0.500000
# [  3.47499807e-14  -1.17961196e-13]
# 0.700000,7.000000,0.600000
# [ -3.95625610e-10   1.21009252e-09]
# 0.700000,7.000000,0.700000
# [  1.61192034e-10  -4.48129530e-10]
# 0.700000,7.000000,0.800000
# [  5.89627010e-11  -1.49009124e-10]
# 0.700000,8.000000,0.100000
# [  3.42067694e-12  -1.47244821e-11]
# 0.700000,8.000000,0.200000
# [  5.24233434e-15  -1.97758476e-14]
# 0.700000,8.000000,0.300000
# [ -1.70131270e-13   5.88338406e-13]
# 0.700000,8.000000,0.400000
# [ -4.80084722e-14   1.51559321e-13]
# 0.700000,8.000000,0.500000
# [  1.09964121e-14  -3.19605453e-14]
# 0.700000,8.000000,0.600000
# [  3.51420282e-14  -9.45667156e-14]
# 0.700000,8.000000,0.700000
# [  4.83502127e-14  -1.21111454e-13]
# 0.700000,8.000000,0.800000
# [ -5.02526265e-10   1.17600895e-09]
# 0.700000,9.000000,0.100000
# [  4.69294222e-12  -1.62605762e-11]
# 0.700000,9.000000,0.200000
# [  4.26303090e-13  -1.36328102e-12]
# 0.700000,9.000000,0.300000
# [ -3.40578260e-13   1.01188849e-12]
# 0.700000,9.000000,0.400000
# [ -2.46946560e-13   6.85243529e-13]
# 0.700000,9.000000,0.500000
# [ -9.54791801e-14   2.48613630e-13]
# 0.700000,9.000000,0.600000
# [ -1.15862181e-14   2.84459956e-14]
# 0.700000,9.000000,0.700000
# [  2.61179967e-14  -6.04377659e-14]
# 0.700000,9.000000,0.800000
# [  4.58678234e-14  -1.00653860e-13]
# 0.800000,6.000000,0.100000
# [ nan  nan]
# 0.800000,6.000000,0.200000
# [ nan  nan]
# 0.800000,6.000000,0.300000
# [ nan  nan]
# 0.800000,6.000000,0.400000
# [  2.51605681e-12  -2.88295707e-11]
# 0.800000,6.000000,0.500000
# [ -1.92749562e-09   1.76634461e-08]
# 0.800000,6.000000,0.600000
# [  3.95338672e-10  -3.15242658e-09]
# 0.800000,6.000000,0.700000
# [  3.95855328e-11  -2.90576768e-10]
# 0.800000,6.000000,0.800000
# [ -1.41268421e-12   7.89080259e-12]
# 0.800000,7.000000,0.100000
# [ nan  nan]
# 0.800000,7.000000,0.200000
# [ -2.05638458e-12   2.23773500e-11]
# 0.800000,7.000000,0.300000
# [  1.48698762e-13  -1.37353323e-12]
# 0.800000,7.000000,0.400000
# [  3.01515757e-13  -2.46724516e-12]
# 0.800000,7.000000,0.500000
# [  2.71194525e-13  -2.01043002e-12]
# 0.800000,7.000000,0.600000
# [ -6.68524236e-10   4.55841807e-09]
# 0.800000,7.000000,0.700000
# [  2.36573431e-10  -1.50175970e-09]
# 0.800000,7.000000,0.800000
# [  1.14576317e-10  -6.85220035e-10]
# 0.800000,8.000000,0.100000
# [ -2.20446057e-12   2.01046714e-11]
# 0.800000,8.000000,0.200000
# [ -7.92614238e-13   6.53586733e-12]
# 0.800000,8.000000,0.300000
# [ -1.33495645e-14   1.00558450e-13]
# 0.800000,8.000000,0.400000
# [  2.13102105e-13  -1.49691197e-12]
# 0.800000,8.000000,0.500000
# [  2.82517065e-13  -1.85602922e-12]
# 0.800000,8.000000,0.600000
# [  2.87322249e-13  -1.77727624e-12]
# 0.800000,8.000000,0.700000
# [  1.66247224e-13  -9.73689879e-13]
# 0.800000,8.000000,0.800000
# [ -4.68419858e-10   2.60992497e-09]
# 0.800000,9.000000,0.100000
# [ -2.48946003e-12   1.89852890e-11]
# 0.800000,9.000000,0.200000
# [ -1.39824870e-12   9.97910088e-12]
# 0.800000,9.000000,0.300000
# [ -4.04850632e-13   2.72099183e-12]
# 0.800000,9.000000,0.400000
# [  5.83769144e-14  -3.72079104e-13]
# 0.800000,9.000000,0.500000
# [  2.33699345e-13  -1.41437036e-12]
# 0.800000,9.000000,0.600000
# [  2.98865967e-13  -1.72610364e-12]
# 0.800000,9.000000,0.700000
# [  3.26162708e-13  -1.80368394e-12]
# 0.800000,9.000000,0.800000
# [  3.17335568e-13  -1.68520406e-12]

# %%
#OK没问题，再看看三维的和实际算出来的对比

# %%
e=0.5;p=6;iota=np.pi/6;spin=0.5
E,Lz,Q=getELQ(e,p,iota,spin)

# %%
M=2e5;d1=0;d2=0;d3=0
filename='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filename,unpack=True)

# %%
getfreq_dt_frommaxi(t,r,phi)
# Out:
# (0.023798535655624255, 0.054008372979892361)

# %%
freq3_dt(e,p,iota,spin)
# Out:
# (0.023801140997356623, 0.050316204727087616, 0.054021279146088001)

# %%
e=0.5;p=6;iota=np.pi/6;spin=0.5
E,Lz,Q=getELQ(e,p,iota,spin)
print('%.10f  %.10f  %.10f'%(E,Lz,Q))
# Out:
# 0.9459823663  2.7544435122  2.5355561891

# %%
M=2e5;d1=0;d2=0;d3=0
filename='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filename,unpack=True)

# %%
getfreq_dt_frommaxi(t,r,phi)
# Out:
# (0.023801141631570627, 0.054021601751330951)

# %%
freq3_dt(e,p,iota,spin)
# Out:
# (0.023801140997356623, 0.050316204727087616, 0.054021279146088001)

# %%
getfreq_dt_fromepa(e,p,spin)
# Out:
# (0.02493744335359075, 0.05232063864714793)

# %%
#由序列获得orbital frequency(对t的),这个序列必须是从r最大值开始的
#p=np.mean(r)
#2018-10-10 最大值处如果两个数正好在第十位小数都相等，会出问题（这个点会没算进去），所以稍微改了一下
tol=9e-11 #数据里r的精度是1e-10
omgr=[]
omgphi=[]
indr=[]
phi=phi-phi[0]
n=1
for i in np.arange(t.size-1):
    if i==0:
        indr.append(i)
    elif(r[i]-r[i-1]>tol and r[i+1]-r[i]<-tol):
        indr.append(i)
############2018-10-10##############
    elif(r[i]-r[i-1]>tol and np.abs(r[i+1]-r[i])<tol  ):
        testi=[]
        for jj in range(100):
            testi.append(i+jj)
            if r[i+jj+1]-r[i+jj]<-tol:
                break

        indr.append(int(round(np.mean(np.array(testi) ) ) ) )
############2018-10-10##################

#####2018-10-29 theta的ind
indth=[]
omgth=[]
for i in np.arange(tau.size-1):
    if i==0:
        indth.append(i)
    elif th[i]<=np.pi/2 and th[i+1]>np.pi/2:
        indth.append(i)

for ii in np.arange(len(indr)):
    if ii==0:
        continue
    omgr.append(2*np.pi/(t[indr[ii]]-t[indr[ii-1]]))
    omgphi.append((phi[indr[ii]]-phi[indr[ii-1]])/(t[indr[ii]]-t[indr[ii-1]]))

indth=indth[0:799]
for jj in np.arange(len(indth)):
    if jj==0:
        continue
    omgth.append(2.0*np.pi/(t[indth[jj]]-t[indth[jj-1]]))
omgr=np.array(omgr)
avgomgr=np.mean(omgr)
avgomgphi=np.mean(np.array(omgphi))
avgomgth=np.mean(np.array(omgth))

#2018-10-29:试试直接数周期来当做omg
numofcyc=len(indr)-1
period=(t[indr[-1]]-t[indr[0]])/float(numofcyc)
dphi=(phi[indr[-1]]-phi[indr[0]])/float(numofcyc)
newomgr=2.0*np.pi/period
newomgphi=dphi/period
numofcycth=len(indth)-1
periodth=(t[indth[-1]]-t[indth[0]])/float(numofcycth)
newomgth=2.0*np.pi/periodth

# %%
plt.plot(range(len(omgth)),omgth)
plt.xlim(0,800)
# Out:
# (0, 800)

# %%
plt.plot(range(len(omgth)),omgth)
plt.xlim(1900,2000)
# Out:
# (1900, 2000)

# %%
newomgr,newomgth,newomgphi
# Out:
# (0.02379849661523753, 0.050287153882283442, 0.054008345290548813)

# %%
newomgr,newomgth,newomgphi ##时间久反而偏的更远了，是不是因为时间久误差积累了？那取时间短的看看？
# Out:
# (0.023775075943335593, 0.050206474503764822, 0.053900976307650596)

# %%
newomgr,newomgth,newomgphi ##时间短的好像r,phi的确实好一点，但是th方向的实在差太远。。。。
# Out:
# (0.023800540720688539, 0.050194426275765675, 0.054025625170205489)

# %%
newomgr,newomgth,newomgphi ##th截到正好几个波节，又会太大。。。
# Out:
# (0.023800540720688539, 0.050416747636440176, 0.054025625170205489)

# %%
newomgr,newomgth,newomgphi ##dt取小一点，到0.1
# Out:
# (0.023801141476397464, 0.050331722192140972, 0.054021605950000259)

# %%
newomgr,newomgth,newomgphi ##dt取小一点，到0.1,这个基础上再截到波节
# Out:
# (0.023801141476397464, 0.050314717404360082, 0.054021605950000259)

# %%
avgomgr,avgomgth,avgomgphi
# Out:
# (0.023798535655624255, 0.05985550655401671, 0.054008372984806076)

# %%
avgomgr,avgomgth,avgomgphi
# Out:
# (0.023775158805757462, 0.059758053362566808, 0.053901113690142437)

# %%
avgomgr,avgomgth,avgomgphi
# Out:
# (0.023800573753435115, 0.059740222092505485, 0.054025630480914265)

# %%
getfreq_dt_frommaxi(t,r,phi)
# Out:
# (0.023798535655624255, 0.054008372984806076)

# %%
getfreq_dt_frommaxi(t,r,phi)
# Out:
# (0.023775158805757462, 0.053901113690142437)

# %%
freq3_dt(e,p,iota,spin)
# Out:
# (0.023801140997356623, 0.050316204727087616, 0.054021279146088001)

# %%
freq3_dt(e,p,iota,spin)
# Out:
# (0.023801140997356623, 0.050316204727087616, 0.054021279146088001)

# %%
freq3_dt(e+1e-2*e,p,iota,spin)
# Out:
# (0.023641883610377005, 0.050046778090562592, 0.053742773367495)

# %%
freq3_dt(e,p+1e-2*p,iota,spin)
# Out:
# (0.023776261714948201, 0.049356622501419402, 0.052918912734256134)

# %%
freq3_dt(e,p,iota+1e-2*iota,spin)
# Out:
# (0.023776819048383468, 0.050349527053400629, 0.054059155119396192)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),th)
plt.xlim(0,2000)
# Out:
# (0, 2000)

# %%
def myfunc_test(x):
    e=x[0]
    p=x[1]
    iota=x[2]
    thisvalue=freq3_dt(e,p,iota,spin)
    stdvalue=np.array([newomgr,newomgth,newomgphi])
    return np.array(thisvalue)-stdvalue

mye,myp,myiota=fsolve(myfunc_test,[e,p,iota])

# %%
e,p,iota
# Out:
# (0.5, 6, 0.5235987755982988)

# %%
mye,myp,myiota
# Out:
# (0.50029881592029102, 5.998360187073831, 0.52164086382974983)

# %%
getELQ(mye,myp,myiota,0.5)
# Out:
# (0.94598455507288925, 2.7571886342007876, 2.5177165719795465)

# %%
myE,myLz,myQ=getELQ(mye,myp,myiota,0.5)

# %%
filename2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,myE,myLz,myQ,d1,d2,d3)

# %%
index, tau2,t2,r2,th2,phi2,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filename2,unpack=True)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(0,100000,0.1),phi)
plt.plot(np.arange(0,len(th2)/10,0.1),phi2,':')
plt.xlim(90000,92000)
# Out:
# (90000, 92000)

# %%
wave1=getwave(filename,np.pi/4,0)
wave2=getwave(filename2,np.pi/4,0)

# %%
bracket(wave1[1],wave2[1],1)/np.sqrt( bracket(wave1[1],wave1[1],1)*bracket(wave2[1],wave2[1],1) )
# Out:
# 0.99901027296318279

# %%
def myfunc_2Dtest(x):
    e=x[0]
    p=x[1]
    #iota=x[2]
    thisvalue=freq3_dt(e,p,iota,spin)
    stdvalue=np.array([newomgr,newomgphi])
    return np.array([thisvalue[0],thisvalue[2]])-stdvalue

# %%
mye2d,myp2d=fsolve(myfunc_2Dtest,[e,p])

# %%
mye2d,myp2d###只调e,p还是OK的
# Out:
# (0.50034062512168387, 5.9993000999178356)

# %%
myE,myLz,myQ=getELQ(mye2d,myp2d,iota,spin)
myE,myLz,myQ
# Out:
# (0.94599916761060932, 2.7544933162133205, 2.5356456581179523)

# %%
myfilename='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,myE,myLz,myQ,d1,d2,d3)

# %%
mywave=getwave(myfilename,np.pi/4,0.)

# %%
E,Lz,Q=getELQ(e,p,iota,spin)
E,Lz,Q
# Out:
# (0.94598236630224186, 2.754443512189142, 2.5355561891122758)

# %%
filename='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
orgwave=getwave(filename,np.pi/4,0)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),orgwave[1])
plt.plot(np.arange(100000),mywave[1],'.')
plt.xlim(98000,100000)
# Out:
# D:\ProgramFiles\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (98000, 100000)

# %%
#OK，那我们就只对着omgr,omgphi调e,p

# %%
#先读一个KRZ的波形：d1=0.2, E=0.94599916761060932,Lz= 2.7544933162133205,Q= 2
d1=0.2; E=0.94599916761060932;Lz= 2.7544933162133205;Q= 2;
spin=0.5;d2=0;d3=0;M=2e5

# %%
filenamekrz='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamekrz,unpack=True)

# %%
ra=np.max(r)
rp=np.min(r)
th_max=np.max(th)
th_min=np.min(th)

# %%
ra,rp,th_max,th_min,th_max+th_min
# Out:
# (12.001610204,
#  4.6503874012999997,
#  2.0846576960999998,
#  1.0569344250999999,
#  3.1415921211999995)

# %%
plt.figure(figsize=[20,5])
plt.plot(t,uth)
plt.xlim(0,2000)
# Out:
# (0, 2000)

# %%
pkrz=2/(1/ra+1/rp)
ekrz=(ra-rp)/(ra+rp)
iotakrz=np.pi/2-th_min

# %%
omgr,omgphi=getfreq_dt_frommaxi(t,r,phi)
omgr,omgphi
# Out:
# (0.025991116896801312, 0.045244166691050559)

# %%
def myfunc_2Dfit(x):
    e=x[0]
    p=x[1]
    #iota=x[2]
    thisvalue=freq3_dt(e,p,iotakrz,spin)
    print(thisvalue)
    stdvalue=np.array([omgr,omgphi])
    return np.array([thisvalue[0],thisvalue[2]])-stdvalue

# %%
ekerr,pkerr=fsolve(myfunc_2Dfit,[ekrz,pkrz])
# Out:
# (0.024622240343715816, 0.0440255419768023, 0.046595758728515776)
# (0.024622240343715816, 0.0440255419768023, 0.046595758728515776)
# (0.024622240343715816, 0.0440255419768023, 0.046595758728515776)
# (0.024622240159808458, 0.044025541675401708, 0.046595758415628179)
# (0.024622240138468105, 0.044025540902768362, 0.046595757525781732)
# (0.025673648894455042, 0.042999250183895429, 0.045206700820844076)
# (0.025906967488016054, 0.042994504130894381, 0.045157104570416363)
# (0.025982840318455758, 0.043060093536407856, 0.045218567898461293)
# (0.025989929723871607, 0.04307856129447573, 0.045238563834083284)
# (0.025991114691820871, 0.04308356574947525, 0.045244121056150999)
# (0.025991116886394553, 0.04308360538343254, 0.045244166422474467)
# (0.025991116896799588, 0.043083605617599136, 0.045244166690992155)

# %%
pkerr,ekerr
# Out:
# (7.2123708271767484, 0.33715606406123505)

# %%
Ekerr,Lkerr,Qkerr=getELQ(ekerr,pkerr,iotakrz,spin)

# %%
filenamekerr='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,Ekerr,Lkerr,Qkerr,0,0,0)

# %%
kerrwave=getwave(filenamekerr,np.pi/4,0)

# %%
krzwave=getwave(filenamekrz,np.pi/4,0)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),kerrwave[1])
plt.plot(np.arange(100000),krzwave[1])
plt.xlim(98000,100000)
# Out:
# D:\ProgramFiles\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (98000, 100000)

# %%
index, tau,tkerr,rkerr,thkerr,phikerr,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamekerr,unpack=True)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),th)
plt.plot(np.arange(100000),thkerr)
plt.xlim(0,1000)
# Out:
# (0, 1000)

# %%
from KRZmetric import *

# %%
freq3_sec(ekrz,pkrz,iotakrz,spin,M)
# Out:
# array([ 0.0249903 ,  0.04468365,  0.04729228])

# %%
ekrz,pkrz,iotakrz
# Out:
# (0.44146191808004176, 6.7033563432931578, 0.51386190169489665)

# %%
def myfunc_mafit(x):
    M=x[0]
    spin=x[1]
    #iota=x[2]
    thisvalue=freq3_sec(ekrz,pkrz,iotakrz,spin,M)
    print(thisvalue)
    stdvalue=np.array([omgr,omgphi])
    return np.array([thisvalue[0],thisvalue[2]])-stdvalue

# %%
from scipy.optimize import fsolve
myM,myspin=fsolve(myfunc_mafit,[M,spin])
# Out:
# [ 0.0249903   0.04468365  0.04729228]
# [ 0.0249903   0.04468365  0.04729228]
# [ 0.0249903   0.04468365  0.04729228]
# [ 0.0249903   0.04468365  0.04729228]
# [ 0.0249903   0.04468365  0.04729228]
# [ 0.0262577   0.04302411  0.04604697]
# [ 0.02636779  0.04287172  0.04593188]
# [ 0.02637953  0.04285652  0.04592058]
# [ 0.02637964  0.04285639  0.04592049]
# [ 0.02637964  0.04285639  0.04592049]

# %%
omgr,omgphi=getfreq_sec_frommaxi(t,r,phi,M)
omgr,omgphi
# Out:
# (0.026379638934633728, 0.045920488370978049)

# %%
omgrk,omgphik=getfreq_sec_frommaxi(tkerr,rkerr,phikerr,M)
omgrk,omgphik
# Out:
# (0.026379375306512801, 0.045919280844436992)

# %%
myM,myspin
# Out:
# (201185.95614090355, 0.63624733565550506)

# %%
Ekerr2,Lzkerr2,Qkerr2=getELQ(ekrz,pkrz,iotakrz,myspin)
Ekerr2,Lzkerr2,Qkerr2
# Out:
# (0.94586315171019897, 2.7452615462048766, 2.4113629593042973)

# %%
ekrz,pkrz,iotakrz
# Out:
# (0.44146191808004176, 6.7033563432931578, 0.51386190169489665)

# %%
filenamekerr2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(myM,myspin,Ekerr2,Lzkerr2,Qkerr2,0,0,0)

# %%
kerrwave2=getwave(filenamekerr2,np.pi/4,0)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(100000),kerrwave2[1])
plt.plot(np.arange(100000),krzwave[1])
plt.xlim(98000,100000)
# Out:
# D:\ProgramFiles\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (98000, 100000)

# %%
index, tau,tkerr2,rkerr2,thkerr2,phikerr2,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamekerr2,unpack=True)

# %%
omgrk2,omgphik2=getfreq_sec_frommaxi(tkerr2,rkerr2,phikerr2,myM)
omgrk2,omgphik2
# Out:
# (0.026378584425171006, 0.045917397465378422)

# %%
omgrk,omgphik=getfreq_sec_frommaxi(tkerr,rkerr,phikerr,M)
omgrk,omgphik
# Out:
# (0.026379375306512801, 0.045919280844436992)

# %%
omgr,omgphi=getfreq_sec_frommaxi(t,r,phi,M)
omgr,omgphi
# Out:
# (0.026379638934633728, 0.045920488370978049)

# %%
M,myM
# Out:
# (200000.0, 204193.33662167509)

# %%
bracket(kerrwave[1],krzwave[1],1)/np.sqrt( bracket(kerrwave[1],kerrwave[1],1)*bracket(krzwave[1],krzwave[1],1) )
# Out:
# 0.74479667422646545

# %%
bracket(kerrwave2[1],krzwave[1],1)/np.sqrt( bracket(kerrwave2[1],kerrwave2[1],1)*bracket(krzwave[1],krzwave[1],1) )
# Out:
# 0.8141258780877817

# %%
getELQ(0.5,6,np.pi/6,0.5)
# Out:
# (0.94598236630224186, 2.754443512189142, 2.5355561891122758)

# %%
from KRZmetric import *
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %%
M=2e5;spin=0.5;d1=0.2;d2=0.;d3=0.;E=0.94598455507288925;Lz=2.7571886342007876;Q=2.403540
filenamekrz='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamekrz,unpack=True)

# %%
#由序列获得orbital frequency(对t的),这个序列必须是从r最大值开始的
#p=np.mean(r)
#2018-10-10 最大值处如果两个数正好在第十位小数都相等，会出问题（这个点会没算进去），所以稍微改了一下
tol=9e-11 #数据里r的精度是1e-10
omgr=[]
omgphi=[]
indr=[]
phi=phi-phi[0]
n=1
for i in np.arange(t.size-1):
    if i==0:
        indr.append(i)
    elif(r[i]-r[i-1]>tol and r[i+1]-r[i]<-tol):
        indr.append(i)
############2018-10-10##############
    elif(r[i]-r[i-1]>tol and np.abs(r[i+1]-r[i])<tol  ):
        testi=[]
        for jj in range(100):
            testi.append(i+jj)
            if r[i+jj+1]-r[i+jj]<-tol:
                break

        indr.append(int(round(np.mean(np.array(testi) ) ) ) )
############2018-10-10##################

#####2018-10-29 theta的ind
indth=[]
omgth=[]
for i in np.arange(tau.size-1):
    if i==0:
        indth.append(i)
    elif th[i]<=np.pi/2 and th[i+1]>np.pi/2:
        indth.append(i)

for ii in np.arange(len(indr)):
    if ii==0:
        continue
    omgr.append(2*np.pi/(t[indr[ii]]-t[indr[ii-1]]))
    omgphi.append((phi[indr[ii]]-phi[indr[ii-1]])/(t[indr[ii]]-t[indr[ii-1]]))

#indth=indth[0:799]
for jj in np.arange(len(indth)):
    if jj==0:
        continue
    omgth.append(2.0*np.pi/(t[indth[jj]]-t[indth[jj-1]]))
omgr=np.array(omgr)
avgomgr=np.mean(omgr)
avgomgphi=np.mean(np.array(omgphi))
avgomgth=np.mean(np.array(omgth))

#2018-10-29:试试直接数周期来当做omg
numofcyc=len(indr)-1
period=(t[indr[-1]]-t[indr[0]])/float(numofcyc)
dphi=(phi[indr[-1]]-phi[indr[0]])/float(numofcyc)
newomgr=2.0*np.pi/period
newomgphi=dphi/period
numofcycth=len(indth)-1
periodth=(t[indth[-1]]-t[indth[0]])/float(numofcycth)
newomgth=2.0*np.pi/periodth

# %%
newomgr,newomgth,newomgphi
# Out:
# (0.025999280678733725, 0.042762623931880607, 0.045269939479742304)

# %%
avgomgr,avgomgth,avgomgphi
# Out:
# (0.025999281029672819, 0.046366215874356617, 0.045269930679460203)

# %%
plt.plot(range(len(omgth)),omgth)
plt.xlim(0,10)
# Out:
# (0, 10)

# %%
ra=np.max(r)
rp=np.min(r)
th_max=np.max(th)
th_min=np.min(th)

# %%
pkrz=2/(1/ra+1/rp)
ekrz=(ra-rp)/(ra+rp)
iotakrz=np.pi/2-th_min

# %%
pkrz,ekrz,iotakrz
# Out:
# (6.6988186891058783, 0.44176569124696319, 0.51166417249489649)

# %%
th_max,th_min,th_max+th_min
# Out:
# (2.0824604995999998, 1.0591321543000001, 3.1415926539000001)

# %%
from scipy.optimize import root
def myfunc_test(x):
    e=x[0]
    p=x[1]
    iota=x[2]
    thisvalue=freq3_dt(e,p,iota,spin)
    print(thisvalue)
    stdvalue=np.array([newomgr,newomgth,newomgphi])
    return np.array(thisvalue)-stdvalue

mye,myp,myiota=fsolve(myfunc_test,[ekrz,pkrz,iotakrz])
mye,myp,myiota
# Out:
# (0.024629333869247632, 0.044054088817372085, 0.046628884485947826)
# (0.024629333869247632, 0.044054088817372085, 0.046628884485947826)
# (0.024629333869247632, 0.044054088817372085, 0.046628884485947826)
# (0.024629333684994262, 0.044054088515360017, 0.046628884172418762)
# (0.024629333664253843, 0.044054087742335865, 0.046628883281936678)
# (0.024629333847521279, 0.044054088839406237, 0.04662888451056469)
# (0.024982939601991383, 0.043722171979161027, 0.046345518106941978)
# (0.024009919729289866, 0.044896730380928521, 0.047655684775414438)
# (0.024695366489550379, 0.043878254767648762, 0.046524806513007083)
# (0.024982939387560632, 0.043722171632005494, 0.046345517745703044)
# (0.024982939369975889, 0.04372217091666189, 0.046345516912835984)
# (0.02498293960263023, 0.043722171978479107, 0.046345518106176743)
# (0.024725215910461517, 0.042999538452791669, 0.04555823631421542)
# (0.025055230307569221, 0.043441065027948735, 0.045974701823193763)
# (0.024837927247396203, 0.043223122837571445, 0.045775914634814611)
# (0.024725215690104514, 0.042999538096898555, 0.045558235943785837)
# (0.02472521567287007, 0.042999537406648469, 0.045558235139684211)
# (0.024725215910323138, 0.042999538452942104, 0.04555823631438416)
# (0.024806236656229736, 0.042973129224011711, 0.045511569057991884)
# (0.025012286681836454, 0.043088914716993131, 0.045602309859283353)
# (0.024438040665050426, 0.043557655919363551, 0.046130754343503028)
# (0.024909457307279337, 0.043051129683428425, 0.045567125026852694)
# (0.025012286475381645, 0.043088914385694975, 0.045602309514684948)
# (0.025012286436878323, 0.043088913682697981, 0.045602308700435329)
# (0.025012286682052211, 0.043088914716769733, 0.045602309859033033)
# (0.024964014580960505, 0.042911377990373221, 0.045405658446012145)
# (0.024929780998023988, 0.043218417699901868, 0.045737090653213165)
# (0.025098504041886117, 0.043113712788691035, 0.045614499278080582)
# (0.024986440238684352, 0.043003169633747895, 0.045498364994365048)
# (0.025037540215136482, 0.04294328264076705, 0.04542857915323411)
# (0.025100008964908709, 0.043118918289808385, 0.045615646664254238)
# (0.025080636352726116, 0.043019712056064065, 0.045507718573359224)
# (0.025007219176702417, 0.043004504240158364, 0.045492788390389054)
# (0.025043155991182862, 0.042889014139114799, 0.045363918907794905)
# (0.025079421351088118, 0.043059850229375453, 0.04555099903346696)
# (0.025081364194699727, 0.042989192100905092, 0.045471505061212981)
# (0.025067679221725175, 0.042922744837494947, 0.045398298958734179)
# (0.025095190432251425, 0.04301774069725655, 0.045497892930111104)
# (0.025103162712515562, 0.042978767609884186, 0.045455086537894394)
# (0.02503282103843122, 0.042979165818885272, 0.045457566101120631)
# (0.025077822688127964, 0.042870982143880507, 0.045335643358513436)
# (0.025120355336908262, 0.042984574120028179, 0.045458669854386735)
# (0.025056545699175543, 0.042983950474478928, 0.045459437670042298)
# (0.025086162770714373, 0.042885962317959818, 0.045351424887211791)
# (0.025086162570227184, 0.042885961997758043, 0.045351424554257266)
# (0.025086162519644243, 0.042885961295775342, 0.045351423743680723)
# (0.025086162770717242, 0.042885962317957056, 0.045351424887208461)
# (0.025134881484710336, 0.042965053275487095, 0.045433836472343767)
# (0.025171718630925471, 0.042953173794136865, 0.045412324313467825)
# (0.025265695529081113, 0.042979548014284712, 0.045423717706518416)
# (0.025165612634057484, 0.042922080509014936, 0.045353994385614854)
# (0.025249959870466673, 0.042853324254230274, 0.045276638640888552)
# (0.02524714392785448, 0.043048927248647874, 0.045492294789526475)
# (0.025321184748347957, 0.042982979884488917, 0.045415805672600756)
# (0.025269050693776076, 0.042935417045223488, 0.045368217920282131)
# (0.025284230543512313, 0.042903271231383919, 0.045327564651205882)
# (0.025321184559213547, 0.042982979583932823, 0.045415805360244331)
# (0.025321184491756916, 0.042982978870162641, 0.045415804539635465)
# (0.025321184748402524, 0.042982979884435731, 0.045415805672541686)
# (0.025313749401313618, 0.04292496030562476, 0.045349664848891837)
# (0.025382559705271947, 0.042995464212867165, 0.045418115236898496)
# (0.025333644742804095, 0.042919003492804593, 0.045334192051742654)
# (0.025348625897234401, 0.042904239476654768, 0.045316803670156211)
# (0.025403680261395806, 0.042981689693098013, 0.0453976919755784)
# (0.025370999157697756, 0.042896147689608317, 0.045300160678764786)
# (0.025394324103184394, 0.043011639315132834, 0.045425913089633424)
# (0.025348514061769214, 0.043054807417071683, 0.045473819013513467)
# (0.025370998973705414, 0.042896147397977112, 0.045300160375766813)
# (0.025370998898205745, 0.042896146681626994, 0.045300159554045982)
# (0.025370999157192545, 0.042896147690093339, 0.045300160679307352)
# (0.025460369512881879, 0.043015749013035717, 0.045423602191895882)
# (0.025413689927189072, 0.042923983325676755, 0.045327352304528647)
# (0.025439294479269479, 0.043178415840793939, 0.04559150301872486)
# (0.025485527914183036, 0.042991117120197327, 0.045390653217390192)
# (0.025395921694814309, 0.04298870938415271, 0.045395565126757485)
# (0.02545118762200254, 0.042900291877620608, 0.045292794094287638)
# (0.025490637830297647, 0.042989324163423118, 0.045387389821471731)
# (0.02549122706251964, 0.04296626341564861, 0.045361595652162502)
# (0.025463110801087326, 0.042908315981787522, 0.045297628156944943)
# (0.025474807068448371, 0.042902146193879991, 0.045290096377435737)
# (0.025508507314558108, 0.042980543151067772, 0.045373283705958299)
# (0.025511000989157762, 0.042958529359632229, 0.045348483834670786)
# (0.025483639278821, 0.042903347285579076, 0.045287564881328735)
# (0.025496027196532624, 0.042895857715940962, 0.045278384611498322)
# (0.0255251773340501, 0.042970973415032261, 0.045358678642615863)
# (0.025529684961910597, 0.042952058359184531, 0.045337019055213437)
# (0.025502577249375633, 0.04290333330177544, 0.045283336214269519)
# (0.025515314587635594, 0.042892632589968269, 0.045270651907958766)
# (0.025538332523076718, 0.042962282461512596, 0.045345853095025014)
# (0.025544745139639478, 0.042945705759719607, 0.045326416261417368)
# (0.025518329913189263, 0.042905396292577842, 0.045282136278908085)
# (0.025531134837677737, 0.042890947930329874, 0.045265431560731609)
# (0.025548770157449451, 0.042954741722165769, 0.045334955425373163)
# (0.025556394628219119, 0.042940359776831652, 0.045317697373950014)
# (0.025531048033839439, 0.042907549429003024, 0.045281736344652608)
# (0.025543347077520231, 0.04289029800037597, 0.045262161573347878)
# (0.025557004531966038, 0.04294836180502299, 0.045325854217343711)
# (0.025564963100556105, 0.042936267139890918, 0.04531109583845648)
# (0.025540918883772485, 0.042909422612072846, 0.045281688458601775)
# (0.025552218727429323, 0.042890900708596823, 0.045261042802955946)
# (0.025563042623326093, 0.04294300963143536, 0.045318365968382478)
# (0.025570611634122352, 0.042933462007046279, 0.045306622880402742)
# (0.025556497396390217, 0.042902841419598471, 0.045272698176477194)
# (0.025561840114580098, 0.042899346221446845, 0.045268740470448265)
# (0.025586849378671121, 0.042940698095388634, 0.045312126376206061)
# (0.025559643706536492, 0.042914614868251814, 0.045285503271335181)
# (0.025570536696339994, 0.042896481467591688, 0.045263597385277694)
# (0.02558907222348351, 0.042937854666307042, 0.045307322438527246)
# (0.025580749979640004, 0.042899564969949178, 0.045265265971687542)
# (0.025565229003336295, 0.04297020781458627, 0.045343715165249598)
# (0.025603105554712076, 0.042966289856173574, 0.045337752280290945)
# (0.025580749805728692, 0.042899564695862542, 0.045265265687052594)
# (0.025580749713536872, 0.042899563971270399, 0.045265264859120011)
# (0.025580749979645222, 0.04289956496994423, 0.045265265971682206)
# (0.025621496864114229, 0.042956446818747933, 0.045323395401804516)
# (0.025598818159171737, 0.042898498971690013, 0.045259384443198339)
# (0.025629113111298049, 0.04296594024068736, 0.045330776104466834)
# (0.025621557052936807, 0.042969415048040048, 0.04533403839939569)
# (0.025598817986572885, 0.04289849869981005, 0.045259384160873654)
# (0.02559881789254613, 0.042898497973987176, 0.045259383331944666)
# (0.025598818159056683, 0.04289849897179631, 0.045259384443316994)
# (0.025639652544936522, 0.042953760445021923, 0.045315889313179619)
# (0.025618590199576911, 0.042896799262727589, 0.045254167404295519)
# (0.025621598823810075, 0.04298643973190823, 0.045350325118405359)
# (0.025655381062257728, 0.042973162480919078, 0.045335425860672199)
# (0.025618590027832643, 0.042896798992348308, 0.045254167123540044)
# (0.025618589932271667, 0.042896798265910349, 0.045254166294184363)
# (0.025618590199594789, 0.042896799262711241, 0.045254167404277332)
# (0.025659414974355692, 0.042955116978876412, 0.045314039813141499)
# (0.025635485249289998, 0.042902239304724053, 0.045256287955645923)
# (0.025668846022706089, 0.042968126962594187, 0.045325163032395421)
# (0.025661949744455053, 0.04297042271473684, 0.045327240035595476)
# (0.025635485078646804, 0.042902239036181837, 0.045256287676813368)
# (0.025635484981605599, 0.042902238308552533, 0.045256286846424583)
# (0.025635485249180762, 0.042902239304824175, 0.045256287955758118)
# (0.025672354354102069, 0.042945990996948985, 0.045300169123020415)
# (0.025652662714420803, 0.042895953548272386, 0.045246153190248335)
# (0.025651985044832477, 0.042980350784444947, 0.045336692703754469)
# (0.025685995065704931, 0.042967865231856306, 0.045323007108910879)
# (0.025652662544591372, 0.04289595328116283, 0.045246152912914242)
# (0.025652662446060254, 0.04289595255304994, 0.045246152082245042)
# (0.025652662714443508, 0.042895953548251695, 0.045246153190225284)
# (0.025689879821199468, 0.042949133646687003, 0.045300843310165526)
# D:\ProgramFiles\lib\site-packages\scipy\optimize\minpack.py:161: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# (0.41484866683913951, 6.8587631331174634, -0.0050658037165972215)

# %%
filenamekerr='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
#####################################2018-11-1 三维下，调spin,M,p可以搞一搞#####################
E,Lz,Q=getELQ(0.2,8,np.pi/4,0.5)
E,Lz,Q
# Out:
# (0.94696535504915469, 2.39975384866539, 5.7717256112264304)

# %%
#E=0.94589652471825014; Lz= 3.3004165358647404;
#E=0.94598455507288925;Lz=2.7571886342007876
#Q=3.472195
d1=0.2
Q=5.625037
filenamekrz2='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(M,spin,E,Lz,Q,d1,d2,d3)

# %%
index, tau,t,r,th,phi,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamekrz2,unpack=True)

# %%
#由序列获得orbital frequency(对t的),这个序列必须是从r最大值开始的
#p=np.mean(r)
#2018-10-10 最大值处如果两个数正好在第十位小数都相等，会出问题（这个点会没算进去），所以稍微改了一下
tol=9e-11 #数据里r的精度是1e-10
omgr=[]
omgphi=[]
indr=[]
phi=phi-phi[0]
n=1
for i in np.arange(t.size-1):
    if i==0:
        indr.append(i)
    elif(r[i]-r[i-1]>tol and r[i+1]-r[i]<-tol):
        indr.append(i)
############2018-10-10##############
    elif(r[i]-r[i-1]>tol and np.abs(r[i+1]-r[i])<tol  ):
        testi=[]
        for jj in range(100):
            testi.append(i+jj)
            if r[i+jj+1]-r[i+jj]<-tol:
                break

        indr.append(int(round(np.mean(np.array(testi) ) ) ) )
############2018-10-10##################

#####2018-10-29 theta的ind
indth=[]
omgth=[]
for i in np.arange(tau.size-1):
    if i==0:
        indth.append(i)
    elif th[i]<=np.pi/2 and th[i+1]>np.pi/2:
        indth.append(i)

for ii in np.arange(len(indr)):
    if ii==0:
        continue
    omgr.append(2*np.pi/(t[indr[ii]]-t[indr[ii-1]]))
    omgphi.append((phi[indr[ii]]-phi[indr[ii-1]])/(t[indr[ii]]-t[indr[ii-1]]))

#indth=indth[0:799]
for jj in np.arange(len(indth)):
    if jj==0:
        continue
    omgth.append(2.0*np.pi/(t[indth[jj]]-t[indth[jj-1]]))
omgr=np.array(omgr)
avgomgr=np.mean(omgr)
avgomgphi=np.mean(np.array(omgphi))
avgomgth=np.mean(np.array(omgth))

#2018-10-29:试试直接数周期来当做omg
numofcyc=len(indr)-1
period=(t[indr[-1]]-t[indr[0]])/float(numofcyc)
dphi=(phi[indr[-1]]-phi[indr[0]])/float(numofcyc)
newomgr=2.0*np.pi/period
newomgphi=dphi/period
numofcycth=len(indth)-1
periodth=(t[indth[-1]]-t[indth[0]])/float(numofcycth)
newomgth=2.0*np.pi/periodth

# %%
newomgr,newomgth,newomgphi
# Out:
# (0.026060652310101934, 0.038740621288606794, 0.040323799610088591)

# %%
plt.plot(range(len(omgth)),omgth)
plt.xlim(0,100)
# Out:
# (0, 100)

# %%
plt.figure(figsize=[20,5])
plt.plot(t,th)
plt.xlim(0,2000)
# Out:
# (0, 2000)

# %%
ra=np.max(r)
rp=np.min(r)
th_max=np.max(th)
th_min=np.min(th)

# %%
pkrz=2/(1/ra+1/rp)
ekrz=(ra-rp)/(ra+rp)
iotakrz=np.pi/2-th_min

# %%
pkrz,ekrz,iotakrz
# Out:
# (8.2299961876069023, 0.17700038123930986, 0.77894929506489652)

# %%
from scipy.optimize import root
def myfunc_test(x):
    e=x[0]
    p=x[1]
    #iota=x[2]
    iota=0
    thisvalue=getfreq_dt_fromepa(e,p,spin)#freq3_dt(e,p,iota,spin)
    print(thisvalue)
    stdvalue=np.array([newomgr,newomgphi])
    return np.array([thisvalue[0],thisvalue[1]])-stdvalue

mye,myp=fsolve(myfunc_test,[ekrz,pkrz])
mye,myp,myiota
# Out:
# (0.026241179877826412, 0.04010170588296487)
# (0.026241179877826412, 0.04010170588296487)
# (0.026241179877826412, 0.04010170588296487)
# (0.02624117984989558, 0.04010170584183281)
# (0.02624117952397483, 0.040101704993314426)
# (0.025942145037031145, 0.04016383157734823)
# (0.026088705191576446, 0.0403678669701618)
# (0.026060340585358898, 0.04032300856098252)
# (0.026060710442608548, 0.04032390791531684)
# (0.026060653058814037, 0.04032380105972231)
# (0.0260606523083393, 0.04032379960667499)
# (0.026060652310101982, 0.040323799610088674)
# (0.22888473366385481, 8.0727229428825993, 0.011047991382082345)

# %%
#from scipy.optimize import root
#调M,a,e试试？
stdvalue=[newomgr,newomgth,newomgphi]
stdvalue=np.array(stdvalue)
Grav=6.674e-11 #引力常数
clight=2.998e8 #光速
Msol=1.989e30  #太阳质量，以千克做单位

#把频率换成s^-1
stdsec=stdvalue*clight**3/M/Msol/Grav
def myfunc_test(x):
    M=x[0]
    spin=x[1]
    p=x[2]
    #iota=0
    thisvalue=freq3_sec(ekrz,p,iotakrz,spin,M)
    #print(thisvalue)

    print('current: %f,%f,%f, target: %f,%f,%f'%(thisvalue[0],thisvalue[1],thisvalue[2],stdsec[0],stdsec[1],stdsec[2]))
    return np.array(thisvalue)-stdsec

myM,myspin,myp=fsolve(myfunc_test,[M,spin,pkrz])
myM,myspin,myp
#newomgr,newomgth,newomgphi
# Out:
# current: 0.025556,0.039789,0.041395, target: 0.026450,0.039320,0.040927
# current: 0.025556,0.039789,0.041395, target: 0.026450,0.039320,0.040927
# current: 0.025556,0.039789,0.041395, target: 0.026450,0.039320,0.040927
# current: 0.025556,0.039789,0.041395, target: 0.026450,0.039320,0.040927
# current: 0.025556,0.039789,0.041395, target: 0.026450,0.039320,0.040927
# current: 0.025556,0.039789,0.041395, target: 0.026450,0.039320,0.040927
# current: 0.026453,0.039468,0.041077, target: 0.026450,0.039320,0.040927
# current: 0.026443,0.039329,0.040935, target: 0.026450,0.039320,0.040927
# current: 0.026451,0.039320,0.040927, target: 0.026450,0.039320,0.040927
# current: 0.026450,0.039320,0.040927, target: 0.026450,0.039320,0.040927
# current: 0.026450,0.039320,0.040927, target: 0.026450,0.039320,0.040927
# current: 0.026450,0.039320,0.040927, target: 0.026450,0.039320,0.040927
# current: 0.026450,0.039320,0.040927, target: 0.026450,0.039320,0.040927
# (187545.42382690511, 0.5492086541878366, 8.6453827249886732)

# %%
newomgr,newomgth,newomgphi
# Out:
# (0.026060652310101934, 0.038740621288606794, 0.040323799610088591)

# %%
freq3_sec(ekrz,myp,iotakrz,myspin,myM)
# Out:
# array([ 0.02645021,  0.03931973,  0.04092657])

# %%
ekrz,myp,iotakrz,myspin,myM
# Out:
# (0.17700038123930986,
#  8.6453827249886732,
#  0.77894929506489652,
#  0.5492086541878366,
#  187545.42382690511)

# %%
#myspin,myM=0.5492086541878366,187545.42382690511
Ek,Lzk,Qk=getELQ(ekrz,myp,iotakrz,myspin)
Ek,Lzk,Qk#=0.94957097495844789, 2.4590066203985526, 5.9073622242654462

# %%
filenamekerr='C:\\Users\\HP\\Documents\\Visual Studio 2015\\Projects\\3D\\3D\\trace_M%.0f_spin%.6f_E%.6f_Lz%.6f_Q%.6f_d1%.6f_d2%.6f_d3%.6f.dat'%(myM,myspin,Ek,Lzk,Qk,0,0,0)

# %%
index, tauk,tk,rk,thk,phik,ut,ur,uth,uphi,F_t,F_r,F_th,F_phi=np.loadtxt(filenamekerr,unpack=True)

# %%
#由序列获得orbital frequency(对t的),这个序列必须是从r最大值开始的
#p=np.mean(r)
#2018-10-10 最大值处如果两个数正好在第十位小数都相等，会出问题（这个点会没算进去），所以稍微改了一下
tol=9e-11 #数据里r的精度是1e-10
omgrk=[]
omgphik=[]
indr=[]
phik=phik-phik[0]
n=1
for i in np.arange(tk.size-1):
    if i==0:
        indr.append(i)
    elif(rk[i]-rk[i-1]>tol and rk[i+1]-rk[i]<-tol):
        indr.append(i)
############2018-10-10##############
    elif(rk[i]-rk[i-1]>tol and np.abs(rk[i+1]-rk[i])<tol  ):
        testi=[]
        for jj in range(100):
            testi.append(i+jj)
            if rk[i+jj+1]-rk[i+jj]<-tol:
                break

        indr.append(int(round(np.mean(np.array(testi) ) ) ) )
############2018-10-10##################

#####2018-10-29 theta的ind
indth=[]
omgthk=[]
for i in np.arange(tauk.size-1):
    if i==0:
        indth.append(i)
    elif thk[i]<=np.pi/2 and thk[i+1]>np.pi/2:
        indth.append(i)

for ii in np.arange(len(indr)):
    if ii==0:
        continue
    omgrk.append(2*np.pi/(tk[indr[ii]]-tk[indr[ii-1]]))
    omgphik.append((phik[indr[ii]]-phik[indr[ii-1]])/(tk[indr[ii]]-tk[indr[ii-1]]))

#indth=indth[0:799]
for jj in np.arange(len(indth)):
    if jj==0:
        continue
    omgthk.append(2.0*np.pi/(tk[indth[jj]]-tk[indth[jj-1]]))
omgrk=np.array(omgrk)
avgomgrk=np.mean(omgrk)
avgomgphik=np.mean(np.array(omgphik))
avgomgthk=np.mean(np.array(omgthk))

#2018-10-29:试试直接数周期来当做omg
numofcyc=len(indr)-1
period=(tk[indr[-1]]-tk[indr[0]])/float(numofcyc)
dphi=(phik[indr[-1]]-phik[indr[0]])/float(numofcyc)
newomgrk=2.0*np.pi/period
newomgphik=dphi/period
numofcycth=len(indth)-1
periodth=(tk[indth[-1]]-tk[indth[0]])/float(numofcycth)
newomgthk=2.0*np.pi/periodth

# %%
newomgrk,newomgthk,newomgphik
# Out:
# (0.024437780413651307, 0.036326676284472635, 0.037814275849432963)

# %%
newomgr,newomgth,newomgphi
# Out:
# (0.026060652310101934, 0.038740621288606794, 0.040323799610088591)

# %%
Grav=6.674e-11 #引力常数
clight=2.998e8 #光速
Msol=1.989e30  #太阳质量，以千克做单位
omgk=[newomgrk,newomgthk,newomgphik]
omg=[newomgr,newomgth,newomgphi]
#把频率换成s^-1
omgksec=np.array(omgk)*clight**3/myM/Msol/Grav
omgsec=np.array(omg)*clight**3/M/Msol/Grav
omgksec,omgsec
# Out:
# array([ 0.02645021,  0.03931815,  0.04092825])

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(1000000)/10.0,th-th[0])
plt.plot(np.arange(1000000)/10.0,thk-thk[0])
plt.xlim(90000,92000)
# Out:
# (90000, 92000)

# %%
kerrwave=getwave(filenamekerr,np.pi/4,0)

# %%
krzwave=getwave(filenamekrz2,np.pi/4,0)

# %%
plt.figure(figsize=[20,5])
plt.plot(np.arange(1000000)/10.0,kerrwave[1],'y',label='Kerr')
plt.plot(np.arange(1000000)/10.0,krzwave[1],'k:',label='KRZ')
plt.legend(fontsize=16)
plt.xlabel('retarded time(s)',fontsize=16)
plt.ylabel('$h_\plus$',rotation=0,fontsize=16)
plt.xlim(92000,97000)
#嗯Kerr的用步长1sec的还OK
# Out:
# D:\ProgramFiles\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (92000, 97000)

# %%
1/(iotakrz/np.pi)
# Out:
# 4.0331157284480987

# %%
dt=0.1
bracket(kerrwave[1],krzwave[1],dt)/np.sqrt( bracket(kerrwave[1],kerrwave[1],dt)*bracket(krzwave[1],krzwave[1],dt) )
# Out:
# 0.98732724289774743

# %%
from KRZmetric import *
import numpy as np

# %%
import KRZmetric
omgksec_=KRZmetric.freq3_sec_fromtrace(tk,rk,thk,phik,myM)

'%.30f,%.30f,%.30f'%(omgksec_[0],omgksec_[1],omgksec_[2])
# Out:
# '0.026450213781688700076522025029,0.039318151543982202134053238751,0.040928253846594257747693035299'

# %%
'%.30f,%.30f,%.30f'%(omgksec[0],omgksec[1],omgksec[2])
# Out:
# '0.026450213781688700076522025029,0.039318151543982202134053238751,0.040928253846594257747693035299'
